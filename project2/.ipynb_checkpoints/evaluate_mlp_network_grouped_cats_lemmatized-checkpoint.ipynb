# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare the data

# %% [markdown]
# Data were loaded and cleaned. The cleaning process included getting rid of the punctuation marks and converting the texts into lower case.

# %%
import string

titles = pd.read_csv("./data/medium_post_titles.csv")
titles.drop(columns=["subtitle", "subtitle_truncated_flag"], inplace=True)

titles.title = titles.title.str.replace('[{}]'.format(string.punctuation), '').str.lower()
titles.title = titles.title.str.replace('‘', '')
titles.title = titles.title.str.replace('’', '')
titles.title = titles.title.str.replace('“', '')
titles.title = titles.title.str.replace('”', '')
titles.title = titles.title.str.replace('—', '')

titles.head()
# Out:
#                   category                                              title
# 0                     work  21 conversations  a fun and easy game for team...
# 1             spirituality                         biblical porn at mars hill
# 2                  lgbtqia                        cisgender is that a disease
# 3                 equality  call me nat love black cowboys and the frontie...
# 4  artificial-intelligence              can i train my model on your computer

# %% [markdown]
# In the original data, many categories are highly ralated. 59 categories are regrouped, forming larger categories. There are eventually 50 categories in total.

# %%
related_categories = pd.read_csv("related_categories.csv")
related_categories
# Out:
#                    original                     grouped
# 0             accessibility                equal_rights
# 1                 addiction         substance_addiction
# 2       android-development                 it_industry
# 3                       art             cultural_topics
# 4   artificial-intelligence              datascience_ai
# 5              basic-income            political_topics
# 6                blockchain             finance_economy
# 7                  business          business_marketing
# 8            cryptocurrency             finance_economy
# 9             cybersecurity                    security
# 10             data-science              datascience_ai
# 11                   design                   ux_design
# 12             digital-life                        tech
# 13               disability                equal_rights
# 14                  economy             finance_economy
# 15            election-2020            political_topics
# 16                 equality                equal_rights
# 17                   family                    domestic
# 18                  fiction                  literature
# 19                     film             cultural_topics
# 20              freelancing                        work
# 21                  gadgets                        tech
# 22              gun-control            political_topics
# 23              immigration            political_topics
# 24          ios-development                 it_industry
# 25               javascript                 it_industry
# 26                  justice            political_topics
# 27                  lgbtqia                equal_rights
# 28         machine-learning              datascience_ai
# 29                marketing          business_marketing
# 30            mental-health  mental_health_neuroscience
# 31              mindfulness  mental_health_neuroscience
# 32                    money             finance_economy
# 33                    music             cultural_topics
# 34             neuroscience  mental_health_neuroscience
# 35                parenting                    domestic
# 36                   poetry                  literature
# 37                 politics            political_topics
# 38                  privacy                    security
# 39       product-management                 it_industry
# 40             productivity                        work
# 41              programming                 it_industry
# 42             psychedelics         substance_addiction
# 43               psychology  mental_health_neuroscience
# 44                     race                equal_rights
# 45            relationships                    domestic
# 46                 religion       religion_spirituality
# 47        self-driving-cars                        tech
# 48                sexuality                equal_rights
# 49     software-engineering                 it_industry
# 50             spirituality       religion_spirituality
# 51                 startups          business_marketing
# 52               technology                        tech
# 53                       tv             cultural_topics
# 54                       ux                   ux_design
# 55          venture-capital             finance_economy
# 56            visual-design                   ux_design
# 57                    women                equal_rights
# 58                     work                work_related

# %%
for i in related_categories.index:
    titles.category = titles.category.replace(*related_categories.loc[i])
    
titles.head()
# Out:
#                 category                                              title
# 0           work_related  21 conversations  a fun and easy game for team...
# 1  religion_spirituality                         biblical porn at mars hill
# 2           equal_rights                        cisgender is that a disease
# 3           equal_rights  call me nat love black cowboys and the frontie...
# 4         datascience_ai              can i train my model on your computer

# %% [markdown]
# 20% of the data were held out for testing.

# %%
from sklearn.model_selection import train_test_split

titles_train, titles_test = train_test_split(titles, train_size=0.8, stratify=titles.category.values)

X_train = titles_train.title.values
X_test = titles_test.title.values

y_train = titles_train.category.values
y_test = titles_test.category.values

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The theme labels were converted to one hot representations.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

integer_encoder = LabelEncoder()
integer_train = integer_encoder.fit_transform(y_train).reshape((-1, 1))
integer_test = integer_encoder.transform(y_test).reshape((-1, 1))

onehot_encoder = OneHotEncoder(sparse=False)
onehot_train = onehot_encoder.fit_transform(integer_train)
onehot_test = onehot_encoder.transform(integer_test)

# %% [markdown]
# # Tokenization and vectorization

# %% [markdown]
# We used WorfNet lemmatization to tokenize the titles.

# %%
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize

def lemmatizeTitle(title):
    
    lemmatizer = WordNetLemmatizer()
    lemmatize = lemmatizer.lemmatize
    
    title_words = word_tokenize(title)
    title_lemmas = map(lambda word: lemmatize(word, "v"), title_words)
    lemmatized_title = " ".join(title_lemmas)
    
    return lemmatized_title

for i in range(len(X_train)):
    X_train[i] = lemmatizeTitle(X_train[i]) 
for i in range(len(X_test)):
    X_test[i] = lemmatizeTitle(X_test[i])

# %% [markdown]
# Use TF-IDF to perform bag-of-words vetorization.

# %% [markdown]
# We adopted the Penn Treebank Tokenizer. We did not want to include n-grams because it will significantly increase the size of the vocabulary. Terms that appear less than twice or occur in more than 10% of the docuemnts are rejected. This choice is made based on experience extracting features for a naive Bayes model.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import TreebankWordTokenizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

tokenizer = TreebankWordTokenizer()
vectorizer = TfidfVectorizer(tokenizer=tokenizer.tokenize, ngram_range=(1, 1), stop_words='english', min_df=2, max_df=0.1)

XMatrix_train = vectorizer.fit_transform(X_train)
vocabulary = np.array(vectorizer.get_feature_names())

XMatrix_test = vectorizer.transform(X_test)

# %%
vocabularySize = vocabulary.size
print("Number of terms in the vocabulary: {}".format(vocabularySize))
# Out:
# Number of terms in the vocabulary: 18940

# %% [markdown]
# # Multilayer perceptron network

# %% [markdown]
# ## 2 hidden layers, 256, 256

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from time import time
from keras.models import load_model

layer1 = Dense(256, activation="relu", input_dim=vocabularySize)
layer2 = Dense(256, activation="relu")
outputLayer = Dense(50, activation="softmax")
classifier = Sequential([layer1, layer2, outputLayer])
classifier.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["acc"])

early_stopping = EarlyStopping(monitor="val_acc", mode="max", patience=50, min_delta=1, verbose=2)
best_model_saving = ModelCheckpoint("MLP_best_model.h5", monitor="val_acc", mode="max", save_best_only=True, verbose=2)

start_time = time()
history = classifier.fit(XMatrix_train,onehot_train, epochs=5000, batch_size=2048, validation_data=(XMatrix_test,onehot_test), callbacks=[early_stopping, best_model_saving], verbose=2)
end_time = time()
print("Time elapsed during training: {}".format(end_time - start_time))

classifier = load_model("MLP_best_model.h5")
_, train_accuracy = classifier.evaluate(XMatrix_train, onehot_train, verbose=0)
print("Accuracy on training set: {}".format(train_accuracy))
_, test_accuracy = classifier.evaluate(XMatrix_test, onehot_test, verbose=0)
print("Accuracy on held-out test set: {}".format(test_accuracy))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 101134 samples, validate on 25284 samples
# Epoch 1/5000
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 30s - loss: 3.4946 - acc: 0.1723 - val_loss: 3.0513 - val_acc: 0.2794
#
# Epoch 00001: val_acc improved from -inf to 0.27939, saving model to MLP_best_model.h5
# Epoch 2/5000
#  - 29s - loss: 2.5692 - acc: 0.3988 - val_loss: 2.2914 - val_acc: 0.4296
#
# Epoch 00002: val_acc improved from 0.27939 to 0.42960, saving model to MLP_best_model.h5
# Epoch 3/5000
#  - 33s - loss: 1.9124 - acc: 0.5225 - val_loss: 2.0357 - val_acc: 0.4835
#
# Epoch 00003: val_acc improved from 0.42960 to 0.48351, saving model to MLP_best_model.h5
# Epoch 4/5000
#  - 30s - loss: 1.5387 - acc: 0.6055 - val_loss: 1.9995 - val_acc: 0.4913
#
# Epoch 00004: val_acc improved from 0.48351 to 0.49126, saving model to MLP_best_model.h5
# Epoch 5/5000
#  - 28s - loss: 1.3195 - acc: 0.6530 - val_loss: 2.0391 - val_acc: 0.4900
#
# Epoch 00005: val_acc did not improve from 0.49126
# Epoch 6/5000
#  - 26s - loss: 1.1675 - acc: 0.6886 - val_loss: 2.1083 - val_acc: 0.4813
#
# Epoch 00006: val_acc did not improve from 0.49126
# Epoch 7/5000
#  - 24s - loss: 1.0500 - acc: 0.7173 - val_loss: 2.1809 - val_acc: 0.4762
#
# Epoch 00007: val_acc did not improve from 0.49126
# Epoch 8/5000
#  - 26s - loss: 0.9602 - acc: 0.7378 - val_loss: 2.2679 - val_acc: 0.4678
#
# Epoch 00008: val_acc did not improve from 0.49126
# Epoch 9/5000
#  - 27s - loss: 0.8852 - acc: 0.7563 - val_loss: 2.3506 - val_acc: 0.4618
#
# Epoch 00009: val_acc did not improve from 0.49126
# Epoch 10/5000
#  - 27s - loss: 0.8227 - acc: 0.7712 - val_loss: 2.4358 - val_acc: 0.4566
#
# Epoch 00010: val_acc did not improve from 0.49126
# Epoch 11/5000
#  - 24s - loss: 0.7703 - acc: 0.7857 - val_loss: 2.5204 - val_acc: 0.4556
#
# Epoch 00011: val_acc did not improve from 0.49126
# Epoch 12/5000
#  - 25s - loss: 0.7238 - acc: 0.7973 - val_loss: 2.6048 - val_acc: 0.4511
#
# Epoch 00012: val_acc did not improve from 0.49126
# Epoch 13/5000
#  - 28s - loss: 0.6817 - acc: 0.8081 - val_loss: 2.6854 - val_acc: 0.4501
#
# Epoch 00013: val_acc did not improve from 0.49126
# Epoch 14/5000
#  - 24s - loss: 0.6435 - acc: 0.8181 - val_loss: 2.7684 - val_acc: 0.4453
#
# Epoch 00014: val_acc did not improve from 0.49126
# Epoch 15/5000
#  - 24s - loss: 0.6097 - acc: 0.8271 - val_loss: 2.8542 - val_acc: 0.4437
#
# Epoch 00015: val_acc did not improve from 0.49126
# Epoch 16/5000
#  - 26s - loss: 0.5781 - acc: 0.8357 - val_loss: 2.9372 - val_acc: 0.4395
#
# Epoch 00016: val_acc did not improve from 0.49126
# Epoch 17/5000
#  - 27s - loss: 0.5475 - acc: 0.8451 - val_loss: 3.0208 - val_acc: 0.4356
#
# Epoch 00017: val_acc did not improve from 0.49126
# Epoch 18/5000
#  - 26s - loss: 0.5201 - acc: 0.8531 - val_loss: 3.1054 - val_acc: 0.4355
#
# Epoch 00018: val_acc did not improve from 0.49126
# Epoch 19/5000
#  - 24s - loss: 0.4938 - acc: 0.8613 - val_loss: 3.1776 - val_acc: 0.4310
#
# Epoch 00019: val_acc did not improve from 0.49126
# Epoch 20/5000
#  - 27s - loss: 0.4690 - acc: 0.8688 - val_loss: 3.2612 - val_acc: 0.4315
#
# Epoch 00020: val_acc did not improve from 0.49126
# Epoch 21/5000
#  - 27s - loss: 0.4451 - acc: 0.8758 - val_loss: 3.3460 - val_acc: 0.4286
#
# Epoch 00021: val_acc did not improve from 0.49126
# Epoch 22/5000
#  - 28s - loss: 0.4233 - acc: 0.8820 - val_loss: 3.4239 - val_acc: 0.4277
#
# Epoch 00022: val_acc did not improve from 0.49126
# Epoch 23/5000
#  - 25s - loss: 0.4029 - acc: 0.8884 - val_loss: 3.4978 - val_acc: 0.4268
#
# Epoch 00023: val_acc did not improve from 0.49126
# Epoch 24/5000
#  - 25s - loss: 0.3816 - acc: 0.8945 - val_loss: 3.5812 - val_acc: 0.4248
#
# Epoch 00024: val_acc did not improve from 0.49126
# Epoch 25/5000
#  - 28s - loss: 0.3609 - acc: 0.9014 - val_loss: 3.6525 - val_acc: 0.4235
#
# Epoch 00025: val_acc did not improve from 0.49126
# Epoch 26/5000
#  - 34s - loss: 0.3433 - acc: 0.9067 - val_loss: 3.7274 - val_acc: 0.4207
#
# Epoch 00026: val_acc did not improve from 0.49126
# Epoch 27/5000
#  - 34s - loss: 0.3265 - acc: 0.9109 - val_loss: 3.8029 - val_acc: 0.4210
#
# Epoch 00027: val_acc did not improve from 0.49126
# Epoch 28/5000
#  - 25s - loss: 0.3106 - acc: 0.9161 - val_loss: 3.8681 - val_acc: 0.4206
#
# Epoch 00028: val_acc did not improve from 0.49126
# Epoch 29/5000
#  - 22s - loss: 0.2954 - acc: 0.9205 - val_loss: 3.9380 - val_acc: 0.4201
#
# Epoch 00029: val_acc did not improve from 0.49126
# Epoch 30/5000
#  - 26s - loss: 0.2817 - acc: 0.9241 - val_loss: 4.0130 - val_acc: 0.4196
#
# Epoch 00030: val_acc did not improve from 0.49126
# Epoch 31/5000
#  - 29s - loss: 0.2683 - acc: 0.9283 - val_loss: 4.0693 - val_acc: 0.4164
#
# Epoch 00031: val_acc did not improve from 0.49126
# Epoch 32/5000
#  - 26s - loss: 0.2543 - acc: 0.9325 - val_loss: 4.1468 - val_acc: 0.4170
#
# Epoch 00032: val_acc did not improve from 0.49126
# Epoch 33/5000
#  - 27s - loss: 0.2438 - acc: 0.9354 - val_loss: 4.1955 - val_acc: 0.4154
#
# Epoch 00033: val_acc did not improve from 0.49126
# Epoch 34/5000
#  - 27s - loss: 0.2327 - acc: 0.9383 - val_loss: 4.2666 - val_acc: 0.4153
#
# Epoch 00034: val_acc did not improve from 0.49126
# Epoch 35/5000
#  - 26s - loss: 0.2224 - acc: 0.9411 - val_loss: 4.3172 - val_acc: 0.4160
#
# Epoch 00035: val_acc did not improve from 0.49126
# Epoch 36/5000
#  - 26s - loss: 0.2138 - acc: 0.9436 - val_loss: 4.3816 - val_acc: 0.4153
#
# Epoch 00036: val_acc did not improve from 0.49126
# Epoch 37/5000
#  - 27s - loss: 0.2048 - acc: 0.9454 - val_loss: 4.4367 - val_acc: 0.4131
#
# Epoch 00037: val_acc did not improve from 0.49126
# Epoch 38/5000
#  - 26s - loss: 0.1963 - acc: 0.9479 - val_loss: 4.4940 - val_acc: 0.4127
#
# Epoch 00038: val_acc did not improve from 0.49126
# Epoch 39/5000
#  - 27s - loss: 0.1882 - acc: 0.9499 - val_loss: 4.5319 - val_acc: 0.4116
#
# Epoch 00039: val_acc did not improve from 0.49126
# Epoch 40/5000
#  - 26s - loss: 0.1826 - acc: 0.9519 - val_loss: 4.5847 - val_acc: 0.4127
#
# Epoch 00040: val_acc did not improve from 0.49126
# Epoch 41/5000
#  - 25s - loss: 0.1755 - acc: 0.9537 - val_loss: 4.6338 - val_acc: 0.4128
#
# Epoch 00041: val_acc did not improve from 0.49126
# Epoch 42/5000
#  - 26s - loss: 0.1683 - acc: 0.9560 - val_loss: 4.6802 - val_acc: 0.4118
#
# Epoch 00042: val_acc did not improve from 0.49126
# Epoch 43/5000
#  - 27s - loss: 0.1636 - acc: 0.9570 - val_loss: 4.7243 - val_acc: 0.4127
#
# Epoch 00043: val_acc did not improve from 0.49126
# Epoch 44/5000
#  - 26s - loss: 0.1584 - acc: 0.9583 - val_loss: 4.7653 - val_acc: 0.4123
#
# Epoch 00044: val_acc did not improve from 0.49126
# Epoch 45/5000
#  - 25s - loss: 0.1534 - acc: 0.9593 - val_loss: 4.8009 - val_acc: 0.4124
#
# Epoch 00045: val_acc did not improve from 0.49126
# Epoch 46/5000
#  - 26s - loss: 0.1486 - acc: 0.9602 - val_loss: 4.8443 - val_acc: 0.4111
#
# Epoch 00046: val_acc did not improve from 0.49126
# Epoch 47/5000
#  - 27s - loss: 0.1455 - acc: 0.9612 - val_loss: 4.8776 - val_acc: 0.4120
#
# Epoch 00047: val_acc did not improve from 0.49126
# Epoch 48/5000
#  - 25s - loss: 0.1412 - acc: 0.9619 - val_loss: 4.9141 - val_acc: 0.4111
#
# Epoch 00048: val_acc did not improve from 0.49126
# Epoch 49/5000
#  - 25s - loss: 0.1387 - acc: 0.9624 - val_loss: 4.9477 - val_acc: 0.4100
#
# Epoch 00049: val_acc did not improve from 0.49126
# Epoch 50/5000
#  - 26s - loss: 0.1357 - acc: 0.9633 - val_loss: 4.9815 - val_acc: 0.4100
#
# Epoch 00050: val_acc did not improve from 0.49126
# Epoch 51/5000
#  - 27s - loss: 0.1329 - acc: 0.9635 - val_loss: 5.0078 - val_acc: 0.4105
#
# Epoch 00051: val_acc did not improve from 0.49126
# Epoch 00051: early stopping
# Time elapsed during training: 1363.5426743030548
# Accuracy on training set: 0.6597682282888205
# Accuracy on held-out test set: 0.4912592944154406

# %%
def plotFittingAccuracy(history):
    
    plt.plot(history.history['acc'], label='train set')
    plt.plot(history.history['val_acc'], label='test set')
    
    plt.title("Accuracy during training")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend()
    plt.show()
    
plotFittingAccuracy(history)

# %% [markdown]
# # Precision-recall

# %%
probability = classifier.predict_proba(XMatrix_test)
classList = integer_encoder.classes_

# %%
realLabel = np.equal(np.repeat(np.reshape(y_test, (-1, 1)), len(classList), axis=1), np.repeat(np.reshape(classList, (1, -1)), len(y_test), axis=0))
thresholds = np.arange(0, 1.001, 0.001)
precision = np.zeros((len(thresholds), len(classList)))
recall = np.zeros((len(thresholds), len(classList)))

for i, threshold in enumerate(thresholds):
    predictedLabel = probability >= threshold

    truePoz = (predictedLabel & realLabel).sum(axis = 0)
    falsePoz = (predictedLabel & (realLabel == False)).sum(axis = 0)
    falseNeg = ((predictedLabel == False) & realLabel).sum(axis = 0)

    precision[i, :] = truePoz / (truePoz + falsePoz)
    recall[i, :] = truePoz / (truePoz + falseNeg)
    
averagePrecision = np.nanmean(precision, axis=1)
averageRecall = np.nanmean(recall, axis=1)
minPrecision = np.nanmin(precision, axis=1)
maxPrecision = np.nanmax(precision, axis=1)

# %%
plt.figure(figsize=(9,9))

f_scores = np.linspace(0.2, 0.8, num=4)
for f_score in f_scores:
    x = np.linspace(0.01, 1.15, 115)
    y = f_score * x / (2 * x - f_score)
    plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.25)
    plt.annotate('f1:{0:0.1f}'.format(f_score), xy=(1, y[100] + 0.02))

plt.plot(averageRecall, averagePrecision, label="macro-average precision")
plt.plot(averageRecall, minPrecision, label="min precision", alpha=0.75)
plt.plot(averageRecall, maxPrecision, label="max precision", alpha=0.75)

plt.xlim([-.15, 1.15])
plt.ylim([-.15, 1.15])
plt.gca().set_aspect('equal')
plt.legend(loc="lower left")
plt.title("Multiclass Precision-Recall")
plt.xlabel("macro-average recall")
plt.ylabel("precision")
# Out:
# Text(0, 0.5, 'precision')

# %%
maxProbability = probability.max(axis=1)
classifiedProportion = np.zeros(len(thresholds))
for i, threshold in enumerate(thresholds):
    classifiedProportion[i] = (maxProbability >= threshold).sum() / len(maxProbability)

# %%
plt.figure(figsize=(9,9))

plt.axhline(0.9, color="red",linestyle='dashed', alpha=0.25)
plt.plot(thresholds, averagePrecision, label="macro-average precision")
plt.plot(thresholds, averageRecall, label="macro-average recall")
plt.plot(thresholds, classifiedProportion, label="classified ratio")

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.gca().set_aspect('equal')
plt.legend(loc="center right")
plt.xlabel("threhold")
plt.title("Precision & Recall")
# Out:
# Text(0.5, 1.0, 'Precision & Recall')

# %%
threshold90 = thresholds[averagePrecision >= 0.9].min()
recall90 = averageRecall[threshold90 == thresholds][0]
print("To reach a multiclass average precision more than 90%, the minimum threshold is " + str(threshold90) + "; the corresponding multiclass average recall is " + str(recall90) + ".")
# Out:
# To reach a multiclass average precision more than 90%, the minimum threshold is 0.999; the corresponding multiclass average recall is 0.003973305911230942.
