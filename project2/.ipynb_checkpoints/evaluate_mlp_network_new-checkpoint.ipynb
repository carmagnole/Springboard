# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare the data

# %% [markdown]
# Data were loaded and cleaned. The cleaning process included getting rid of the punctuation marks and converting the texts into lower case.

# %%
import string

titles = pd.read_csv("./data/medium_post_titles.csv")
titles.drop(columns=["subtitle", "subtitle_truncated_flag"], inplace=True)

titles.title = titles.title.str.replace('[{}]'.format(string.punctuation), '').str.lower()
titles.title = titles.title.str.replace('‘', '')
titles.title = titles.title.str.replace('’', '')
titles.title = titles.title.str.replace('“', '')
titles.title = titles.title.str.replace('”', '')
titles.title = titles.title.str.replace('—', '')

titles.head()
# Out:
#                   category                                              title
# 0                     work  21 conversations  a fun and easy game for team...
# 1             spirituality                         biblical porn at mars hill
# 2                  lgbtqia                        cisgender is that a disease
# 3                 equality  call me nat love black cowboys and the frontie...
# 4  artificial-intelligence              can i train my model on your computer

# %% [markdown]
# 20% of the data were held out for testing.

# %%
from sklearn.model_selection import train_test_split

titles_train, titles_test = train_test_split(titles, train_size=0.8, stratify=titles.category.values)

X_train = titles_train.title.values
X_test = titles_test.title.values

y_train = titles_train.category.values
y_test = titles_test.category.values

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The theme labels were converted to one hot representations.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

integer_encoder = LabelEncoder()
integer_train = integer_encoder.fit_transform(y_train).reshape((-1, 1))
integer_test = integer_encoder.transform(y_test).reshape((-1, 1))

onehot_encoder = OneHotEncoder(sparse=False)
onehot_train = onehot_encoder.fit_transform(integer_train)
onehot_test = onehot_encoder.transform(integer_test)

# %% [markdown]
# # Tokenization and vectorization

# %% [markdown]
# Use TF-IDF to perform bag-of-words vetorization.

# %% [markdown]
# We adopted the Penn Treebank Tokenizer. We did not want to include n-grams because it will significantly increase the size of the vocabulary. Terms that appear less than twice or occur in more than 10% of the docuemnts are rejected. This choice is made based on experience extracting features for a naive Bayes model.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import TreebankWordTokenizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

tokenizer = TreebankWordTokenizer()
vectorizer = TfidfVectorizer(tokenizer=tokenizer.tokenize, ngram_range=(1, 3), stop_words='english', min_df=2, max_df=0.1)

XMatrix_train = vectorizer.fit_transform(X_train)
vocabulary = np.array(vectorizer.get_feature_names())

XMatrix_test = vectorizer.transform(X_test)

# %%
vocabularySize = vocabulary.size
print("Number of terms in the vocabulary: {}".format(vocabularySize))
# Out:
# Number of terms in the vocabulary: 55391

# %% [markdown]
# # Multilayer perceptron network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from time import time
from keras.models import load_model

layer1 = Dense(256, activation="relu", input_dim=vocabularySize)
layer2 = Dense(256, activation="relu")
outputLayer = Dense(93, activation="softmax")
classifier = Sequential([layer1, layer2, outputLayer])
classifier.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["acc"])

early_stopping = EarlyStopping(monitor="val_acc", mode="max", patience=50, verbose=2)
best_model_saving = ModelCheckpoint("MLP_best_model.h5", monitor="val_acc", mode="max", save_best_only=True, verbose=2)

start_time = time()
history = classifier.fit(XMatrix_train,onehot_train, epochs=5000, batch_size=2048, validation_data=(XMatrix_test,onehot_test), callbacks=[early_stopping, best_model_saving], verbose=2)
end_time = time()
print("Time elapsed during training: {}".format(end_time - start_time))

classifier = load_model("MLP_best_model.h5")
_, train_accuracy = classifier.evaluate(XMatrix_train, onehot_train, verbose=0)
print("Accuracy on training set: {}".format(train_accuracy))
_, test_accuracy = classifier.evaluate(XMatrix_test, onehot_test, verbose=0)
print("Accuracy on held-out test set: {}".format(test_accuracy))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1020 20:16:04.087215 4576396736 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1020 20:16:04.115415 4576396736 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1020 20:16:04.117519 4576396736 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1020 20:16:04.150906 4576396736 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1020 20:16:04.169510 4576396736 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1020 20:16:04.243875 4576396736 deprecation.py:323] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1020 20:16:04.279840 4576396736 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 101134 samples, validate on 25284 samples
# Epoch 1/5000
#  - 50s - loss: 4.2256 - acc: 0.0751 - val_loss: 3.9135 - val_acc: 0.1553
#
# Epoch 00001: val_acc improved from -inf to 0.15532, saving model to MLP_best_model.h5
# Epoch 2/5000
#  - 58s - loss: 3.3733 - acc: 0.2744 - val_loss: 2.9472 - val_acc: 0.3380
#
# Epoch 00002: val_acc improved from 0.15532 to 0.33796, saving model to MLP_best_model.h5
# Epoch 3/5000
#  - 59s - loss: 2.2508 - acc: 0.4859 - val_loss: 2.5257 - val_acc: 0.4040
#
# Epoch 00003: val_acc improved from 0.33796 to 0.40397, saving model to MLP_best_model.h5
# Epoch 4/5000
#  - 58s - loss: 1.5796 - acc: 0.6221 - val_loss: 2.5286 - val_acc: 0.4058
#
# Epoch 00004: val_acc improved from 0.40397 to 0.40583, saving model to MLP_best_model.h5
# Epoch 5/5000
#  - 58s - loss: 1.1657 - acc: 0.7178 - val_loss: 2.6643 - val_acc: 0.3965
#
# Epoch 00005: val_acc did not improve from 0.40583
# Epoch 6/5000
#  - 53s - loss: 0.8893 - acc: 0.7838 - val_loss: 2.8431 - val_acc: 0.3842
#
# Epoch 00006: val_acc did not improve from 0.40583
# Epoch 7/5000
#  - 52s - loss: 0.7018 - acc: 0.8278 - val_loss: 3.0356 - val_acc: 0.3749
#
# Epoch 00007: val_acc did not improve from 0.40583
# Epoch 8/5000
#  - 54s - loss: 0.5738 - acc: 0.8594 - val_loss: 3.2322 - val_acc: 0.3658
#
# Epoch 00008: val_acc did not improve from 0.40583
# Epoch 9/5000
#  - 56s - loss: 0.4824 - acc: 0.8806 - val_loss: 3.4272 - val_acc: 0.3570
#
# Epoch 00009: val_acc did not improve from 0.40583
# Epoch 10/5000
#  - 51s - loss: 0.4161 - acc: 0.8965 - val_loss: 3.5968 - val_acc: 0.3497
#
# Epoch 00010: val_acc did not improve from 0.40583
# Epoch 11/5000
#  - 50s - loss: 0.3661 - acc: 0.9074 - val_loss: 3.7684 - val_acc: 0.3441
#
# Epoch 00011: val_acc did not improve from 0.40583
# Epoch 12/5000
#  - 50s - loss: 0.3280 - acc: 0.9157 - val_loss: 3.9280 - val_acc: 0.3400
#
# Epoch 00012: val_acc did not improve from 0.40583
# Epoch 13/5000
#  - 50s - loss: 0.2979 - acc: 0.9228 - val_loss: 4.0828 - val_acc: 0.3401
#
# Epoch 00013: val_acc did not improve from 0.40583
# Epoch 14/5000
#  - 49s - loss: 0.2727 - acc: 0.9288 - val_loss: 4.2325 - val_acc: 0.3350
#
# Epoch 00014: val_acc did not improve from 0.40583
# Epoch 15/5000
#  - 52s - loss: 0.2532 - acc: 0.9326 - val_loss: 4.3593 - val_acc: 0.3315
#
# Epoch 00015: val_acc did not improve from 0.40583
# Epoch 16/5000
#  - 54s - loss: 0.2343 - acc: 0.9372 - val_loss: 4.4786 - val_acc: 0.3309
#
# Epoch 00016: val_acc did not improve from 0.40583
# Epoch 17/5000
#  - 52s - loss: 0.2207 - acc: 0.9409 - val_loss: 4.6049 - val_acc: 0.3266
#
# Epoch 00017: val_acc did not improve from 0.40583
# Epoch 18/5000
#  - 55s - loss: 0.2077 - acc: 0.9432 - val_loss: 4.7185 - val_acc: 0.3249
#
# Epoch 00018: val_acc did not improve from 0.40583
# Epoch 19/5000
#  - 55s - loss: 0.1979 - acc: 0.9461 - val_loss: 4.8244 - val_acc: 0.3221
#
# Epoch 00019: val_acc did not improve from 0.40583
# Epoch 20/5000
#  - 54s - loss: 0.1875 - acc: 0.9481 - val_loss: 4.9204 - val_acc: 0.3227
#
# Epoch 00020: val_acc did not improve from 0.40583
# Epoch 21/5000
#  - 52s - loss: 0.1794 - acc: 0.9503 - val_loss: 5.0156 - val_acc: 0.3201
#
# Epoch 00021: val_acc did not improve from 0.40583
# Epoch 22/5000
#  - 65s - loss: 0.1714 - acc: 0.9519 - val_loss: 5.1315 - val_acc: 0.3193
#
# Epoch 00022: val_acc did not improve from 0.40583
# Epoch 23/5000
#  - 71s - loss: 0.1652 - acc: 0.9535 - val_loss: 5.2014 - val_acc: 0.3159
#
# Epoch 00023: val_acc did not improve from 0.40583
# Epoch 24/5000
#  - 61s - loss: 0.1589 - acc: 0.9550 - val_loss: 5.2756 - val_acc: 0.3176
#
# Epoch 00024: val_acc did not improve from 0.40583
# Epoch 25/5000
#  - 61s - loss: 0.1535 - acc: 0.9559 - val_loss: 5.3517 - val_acc: 0.3159
#
# Epoch 00025: val_acc did not improve from 0.40583
# Epoch 26/5000
#  - 68s - loss: 0.1482 - acc: 0.9575 - val_loss: 5.4229 - val_acc: 0.3170
#
# Epoch 00026: val_acc did not improve from 0.40583
# Epoch 27/5000
#  - 69s - loss: 0.1445 - acc: 0.9587 - val_loss: 5.4957 - val_acc: 0.3162
#
# Epoch 00027: val_acc did not improve from 0.40583
# Epoch 28/5000
#  - 67s - loss: 0.1401 - acc: 0.9594 - val_loss: 5.5662 - val_acc: 0.3147
#
# Epoch 00028: val_acc did not improve from 0.40583
# Epoch 29/5000
#  - 58s - loss: 0.1363 - acc: 0.9603 - val_loss: 5.6297 - val_acc: 0.3125
#
# Epoch 00029: val_acc did not improve from 0.40583
# Epoch 30/5000
#  - 57s - loss: 0.1341 - acc: 0.9611 - val_loss: 5.6945 - val_acc: 0.3133
#
# Epoch 00030: val_acc did not improve from 0.40583
# Epoch 31/5000
#  - 49s - loss: 0.1306 - acc: 0.9617 - val_loss: 5.7460 - val_acc: 0.3126
#
# Epoch 00031: val_acc did not improve from 0.40583
# Epoch 32/5000
#  - 49s - loss: 0.1275 - acc: 0.9625 - val_loss: 5.7910 - val_acc: 0.3126
#
# Epoch 00032: val_acc did not improve from 0.40583
# Epoch 33/5000
#  - 49s - loss: 0.1249 - acc: 0.9632 - val_loss: 5.8432 - val_acc: 0.3119
#
# Epoch 00033: val_acc did not improve from 0.40583
# Epoch 34/5000
#  - 50s - loss: 0.1230 - acc: 0.9636 - val_loss: 5.9061 - val_acc: 0.3132
#
# Epoch 00034: val_acc did not improve from 0.40583
# Epoch 35/5000
#  - 49s - loss: 0.1213 - acc: 0.9639 - val_loss: 5.9425 - val_acc: 0.3112
#
# Epoch 00035: val_acc did not improve from 0.40583
# Epoch 36/5000
#  - 49s - loss: 0.1186 - acc: 0.9643 - val_loss: 5.9937 - val_acc: 0.3118
#
# Epoch 00036: val_acc did not improve from 0.40583
# Epoch 37/5000
#  - 49s - loss: 0.1170 - acc: 0.9646 - val_loss: 6.0416 - val_acc: 0.3081
#
# Epoch 00037: val_acc did not improve from 0.40583
# Epoch 38/5000
#  - 49s - loss: 0.1156 - acc: 0.9652 - val_loss: 6.0717 - val_acc: 0.3112
#
# Epoch 00038: val_acc did not improve from 0.40583
# Epoch 39/5000
#  - 50s - loss: 0.1128 - acc: 0.9661 - val_loss: 6.1196 - val_acc: 0.3105
#
# Epoch 00039: val_acc did not improve from 0.40583
# Epoch 40/5000
#  - 49s - loss: 0.1124 - acc: 0.9661 - val_loss: 6.1599 - val_acc: 0.3104
#
# Epoch 00040: val_acc did not improve from 0.40583
# Epoch 41/5000
#  - 49s - loss: 0.1104 - acc: 0.9670 - val_loss: 6.1853 - val_acc: 0.3100
#
# Epoch 00041: val_acc did not improve from 0.40583
# Epoch 42/5000
#  - 50s - loss: 0.1092 - acc: 0.9671 - val_loss: 6.2260 - val_acc: 0.3086
#
# Epoch 00042: val_acc did not improve from 0.40583
# Epoch 43/5000
#  - 49s - loss: 0.1078 - acc: 0.9671 - val_loss: 6.2620 - val_acc: 0.3107
#
# Epoch 00043: val_acc did not improve from 0.40583
# Epoch 44/5000
#  - 50s - loss: 0.1073 - acc: 0.9671 - val_loss: 6.3020 - val_acc: 0.3071
#
# Epoch 00044: val_acc did not improve from 0.40583
# Epoch 45/5000
#  - 50s - loss: 0.1050 - acc: 0.9683 - val_loss: 6.3227 - val_acc: 0.3099
#
# Epoch 00045: val_acc did not improve from 0.40583
# Epoch 46/5000
#  - 50s - loss: 0.1043 - acc: 0.9682 - val_loss: 6.3655 - val_acc: 0.3076
#
# Epoch 00046: val_acc did not improve from 0.40583
# Epoch 47/5000
#  - 50s - loss: 0.1035 - acc: 0.9677 - val_loss: 6.3906 - val_acc: 0.3062
#
# Epoch 00047: val_acc did not improve from 0.40583
# Epoch 48/5000
#  - 50s - loss: 0.1028 - acc: 0.9681 - val_loss: 6.4016 - val_acc: 0.3072
#
# Epoch 00048: val_acc did not improve from 0.40583
# Epoch 49/5000
#  - 50s - loss: 0.1008 - acc: 0.9686 - val_loss: 6.4350 - val_acc: 0.3082
#
# Epoch 00049: val_acc did not improve from 0.40583
# Epoch 50/5000
#  - 49s - loss: 0.1009 - acc: 0.9686 - val_loss: 6.4543 - val_acc: 0.3079
#
# Epoch 00050: val_acc did not improve from 0.40583
# Epoch 51/5000
#  - 50s - loss: 0.0998 - acc: 0.9691 - val_loss: 6.4788 - val_acc: 0.3079
#
# Epoch 00051: val_acc did not improve from 0.40583
# Epoch 52/5000
#  - 50s - loss: 0.0997 - acc: 0.9688 - val_loss: 6.5034 - val_acc: 0.3072
#
# Epoch 00052: val_acc did not improve from 0.40583
# Epoch 53/5000
#  - 50s - loss: 0.0985 - acc: 0.9692 - val_loss: 6.5322 - val_acc: 0.3078
#
# Epoch 00053: val_acc did not improve from 0.40583
# Epoch 54/5000
#  - 51s - loss: 0.0984 - acc: 0.9698 - val_loss: 6.5595 - val_acc: 0.3069
#
# Epoch 00054: val_acc did not improve from 0.40583
# Epoch 00054: early stopping
# Time elapsed during training: 2889.478052854538
# Accuracy on training set: 0.7231791484588607
# Accuracy on held-out test set: 0.4058297737699731

# %%
def plotFittingAccuracy(history):
    
    plt.plot(history.history['acc'], label='train set')
    plt.plot(history.history['val_acc'], label='test set')
    
    plt.title("Accuracy during training")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend()
    plt.show()
    
plotFittingAccuracy(history)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

def reveseOneHot(prediction_output):
    integer_encode = onehot_encoder.inverse_transform(prediction_output).flatten().astype(int)
    return integer_encoder.inverse_transform(integer_encode) 

def plotConfusionMatrix(confusionMatrix, classes):

    confusionMatrix = confusionMatrix.astype('float') / confusionMatrix.sum(axis=1)[:, np.newaxis]
    
    heatmap_df = pd.DataFrame(confusionMatrix, index=classes, columns=classes)
    
    fig, ax = plt.subplots(figsize=(16,13))
    sns.heatmap(heatmap_df, xticklabels=True,yticklabels=True, ax=ax, vmin=0,vmax=1)
    ax.set_aspect("equal")
    plt.title("Confusion Matrix", fontsize=20)
    plt.ylabel("true category", fontsize=15)
    plt.xlabel("predicted category", fontsize=15)

def precisionFromConfusionMatrix(confusionMatrix):
    
    truePos = np.diagonal(confusionMatrix)
    falsePos = np.asarray(confusionMatrix.sum(axis=0)) - truePos
    
    precision = truePos / (truePos + falsePos)
    precision = precision[~np.isnan(precision)]
    
    return precision.mean()

y_pred = reveseOneHot(classifier.predict(XMatrix_test))

category_list = unique_labels(y_test, y_pred)
cMatrix = confusion_matrix(y_test, y_pred, labels=category_list)

plotConfusionMatrix(cMatrix, category_list)

precision = precisionFromConfusionMatrix(cMatrix)
print("Average multiclass precision: {}".format(precision))
# Out:
# Average multiclass precision: 0.43067684825705743

# %% [markdown]
# # Precision-recall

# %%
probability = classifier.predict_proba(XMatrix_test)
classList = integer_encoder.classes_

# %%
realLabel = np.equal(np.repeat(np.reshape(y_test, (-1, 1)), len(classList), axis=1), np.repeat(np.reshape(classList, (1, -1)), len(y_test), axis=0))
thresholds = np.arange(0, 1.001, 0.001)
precision = np.zeros((len(thresholds), len(classList)))
recall = np.zeros((len(thresholds), len(classList)))

for i, threshold in enumerate(thresholds):
    predictedLabel = probability >= threshold

    truePoz = (predictedLabel & realLabel).sum(axis = 0)
    falsePoz = (predictedLabel & (realLabel == False)).sum(axis = 0)
    falseNeg = ((predictedLabel == False) & realLabel).sum(axis = 0)

    precision[i, :] = truePoz / (truePoz + falsePoz)
    recall[i, :] = truePoz / (truePoz + falseNeg)
    
averagePrecision = np.nanmean(precision, axis=1)
averageRecall = np.nanmean(recall, axis=1)
minPrecision = np.nanmin(precision, axis=1)
maxPrecision = np.nanmax(precision, axis=1)

# %%
plt.figure(figsize=(9,9))

f_scores = np.linspace(0.2, 0.8, num=4)
for f_score in f_scores:
    x = np.linspace(0.01, 1.15, 115)
    y = f_score * x / (2 * x - f_score)
    plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.25)
    plt.annotate('f1:{0:0.1f}'.format(f_score), xy=(1, y[100] + 0.02))

plt.plot(averageRecall, averagePrecision, label="macro-average precision")
plt.plot(averageRecall, minPrecision, label="min precision", alpha=0.75)
plt.plot(averageRecall, maxPrecision, label="max precision", alpha=0.75)

plt.xlim([-.15, 1.15])
plt.ylim([-.15, 1.15])
plt.gca().set_aspect('equal')
plt.legend(loc="lower left")
plt.title("Multiclass Precision-Recall")
plt.xlabel("macro-average recall")
plt.ylabel("precision")
# Out:
# Text(0, 0.5, 'precision')

# %%
maxProbability = probability.max(axis=1)
classifiedProportion = np.zeros(len(thresholds))
for i, threshold in enumerate(thresholds):
    classifiedProportion[i] = (maxProbability >= threshold).sum() / len(maxProbability)

# %%
plt.figure(figsize=(9,9))

plt.axhline(0.9, color="red",linestyle='dashed', alpha=0.25)
plt.plot(thresholds, averagePrecision, label="macro-average precision")
plt.plot(thresholds, averageRecall, label="macro-average recall")
plt.plot(thresholds, classifiedProportion, label="classified ratio")

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.gca().set_aspect('equal')
plt.legend(loc="center right")
plt.xlabel("threhold")
plt.title("Precision & Recall")
# Out:
# Text(0.5, 1.0, 'Precision & Recall')

# %%
threshold90 = thresholds[averagePrecision >= 0.9].min()
recall90 = averageRecall[threshold90 == thresholds][0]
print("To reach a multiclass average precision more than 90%, the minimum threshold is " + str(threshold90) + "; the corresponding multiclass average recall is " + str(recall90) + ".")
# Out:
# To reach a multiclass average precision more than 90%, the minimum threshold is 0.99; the corresponding multiclass average recall is 0.010973018867268505.
