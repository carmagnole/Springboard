# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare the data

# %% [markdown]
# Data were loaded and cleaned. The texts were converted to lower case, and all punctuation marks were removed.

# %%
import string

titles = pd.read_csv("./data/medium_post_titles.csv")
titles.drop(columns=["subtitle", "subtitle_truncated_flag"], inplace=True)

titles.title = titles.title.str.replace('[{}]'.format(string.punctuation), '').str.lower()
titles.title = titles.title.str.replace('‘', '')
titles.title = titles.title.str.replace('’', '')
titles.title = titles.title.str.replace('“', '')
titles.title = titles.title.str.replace('”', '')
titles.title = titles.title.str.replace('—', '')

titles.head()
# Out:
#                   category                                              title
# 0                     work  21 conversations  a fun and easy game for team...
# 1             spirituality                         biblical porn at mars hill
# 2                  lgbtqia                        cisgender is that a disease
# 3                 equality  call me nat love black cowboys and the frontie...
# 4  artificial-intelligence              can i train my model on your computer

# %% [markdown]
# 20% of the data were held out as test set.

# %%
from sklearn.model_selection import train_test_split

titles_train, titles_test = train_test_split(titles, train_size=0.8, stratify=titles.category.values)

X_train = titles_train.title.str.split().tolist()
X_test = titles_test.title.str.split().tolist()

y_train = titles_train.category.values
y_test = titles_test.category.values

# %% [markdown]
# Categorical labels were converted to one-hot vector representations.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

integer_encoder = LabelEncoder()
integer_train = integer_encoder.fit_transform(y_train).reshape((-1, 1))
integer_test = integer_encoder.transform(y_test).reshape((-1, 1))

onehot_encoder = OneHotEncoder(sparse=False)
onehot_train = onehot_encoder.fit_transform(integer_train)
onehot_test = onehot_encoder.transform(integer_test)

# %% [markdown]
# The continuous bag-of-words model was used to generate Word2vec embeddings. The continuous bag-of-words method trains a network that can predict the target word given the contextual words around it in the corpus. Word2vec project each word into a high-dimension vector space where contextually close words are located spatially closely.

# %% [markdown]
# Here, individual words, which appeared more than (including) twice in the data in the training set, were mapped to 128-dimension vectors, while the algorithm utilized the 8 words around it in the text as the context. We then coverted the titles in both the training and test sets to sequences of vectors where each vector represents a word. Novel words that were not included in the vocabulary during training were mapped to a vector with all elements equal to 0.

# %% [markdown]
# As the titles were not of equal length, padding was needed. All titles were pre-padded with vectors where all elements are set to 0 so they all have the same length in the final vector-sequence representations.

# %%
from itertools import chain

def extractVocabulary(titles, min_count):
    
    flatten_titles = list(chain(*titles))
    
    vocabulary, counts = np.unique(flatten_titles, return_counts=True)
    vocabulary = vocabulary[counts >= 2]
    
    return vocabulary

# %%
from gensim.sklearn_api import W2VTransformer

vectorLength = 256
vectorizer = W2VTransformer(size=vectorLength, window=3, min_count=2, null_word=1, workers=-2, iter=1000)
vectorizer.fit(X_train)
vocabulary = extractVocabulary(X_train, 2)

# %%
def mapTitle2Vectors(title, vectorizer, vocabulary, vectorSize, maxLength):
    
    vectorsMatrix = np.zeros((maxLength, vectorSize))
    nWords = len(title)
    prePadLength = maxLength - nWords
    for i, word in enumerate(title):
        if word in vocabulary:
            vectorsMatrix[prePadLength + i, :] = vectorizer.transform(word)
            
    return vectorsMatrix

# %%
from multiprocessing import Pool
from multiprocessing import cpu_count
from functools import partial

def mapTitles2Vectors(titles, vectorizer, vocabulary, vectorSize, maxLength):
    
    pool = Pool(cpu_count() - 1)
    
#     nTitles = len(titles)
    
#     representations = [[] for i in range(nTitles)]
#     for i, title in tqdm(enumerate(titles)):
#         representations[i] = mapTitle2Vectors(title, vectorizer, vocabulary, vectorSize, maxLength)
    
    mapTitle2Vectors_partial = partial(mapTitle2Vectors, vectorizer=vectorizer, vocabulary=vocabulary, vectorSize=vectorSize, maxLength=maxLength)
    representations = pool.map(mapTitle2Vectors_partial, titles)
    
    return np.concatenate(list(map(lambda mat: mat[np.newaxis, :], representations)), axis=0)

# %%
maxTitleLength = max(map(len, X_train + X_test))
vectors_train = mapTitles2Vectors(X_train, vectorizer, vocabulary, vectorLength, maxTitleLength)
vectors_test = mapTitles2Vectors(X_test, vectorizer, vocabulary, vectorLength, maxTitleLength)

# %% [markdown]
# # LSTM neural network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from time import time

lstmLayer = LSTM(512, activation="relu", input_shape=(maxTitleLength, vectorLength))
fullyConnectedLayer1 = Dense(512, activation="relu")
fullyConnectedLayer2 = Dense(93, activation="softmax")

classifier = Sequential([lstmLayer, fullyConnectedLayer1, fullyConnectedLayer2])
classifier.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["acc"])

early_stopping = EarlyStopping(monitor='val_acc', mode="max", patience=50, verbose=1)
best_model_saving = ModelCheckpoint("new_LSTM_best_model.h5", monitor="val_acc", mode="max", save_best_only=True, verbose=1)

start_time = time()
history = classifier.fit(vectors_train,onehot_train, epochs=5000, batch_size=2048, validation_data=(vectors_test,onehot_test), callbacks=[early_stopping, best_model_saving], verbose=2)
end_time = time()
print("Time elapsed during training: {}".format(end_time - start_time))

classifier = load_model("new_LSTM_best_model.h5")

_, train_accuracy = classifier.evaluate(vectors_train, onehot_train, verbose=0)
print("Accuracy on training set: {}".format(train_accuracy))
_, test_accuracy = classifier.evaluate(vectors_test, onehot_test, verbose=0)
print("Accuracy on held-out test set: {}".format(test_accuracy))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1009 09:55:26.976733 4714554816 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1009 09:55:27.005946 4714554816 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1009 09:55:27.014010 4714554816 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1009 09:55:27.350661 4714554816 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1009 09:55:27.369521 4714554816 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1009 09:55:27.571742 4714554816 deprecation.py:323] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1009 09:55:27.958431 4714554816 deprecation_wrapper.py:119] From /anaconda3/envs/SpringBoard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 101134 samples, validate on 25284 samples
# Epoch 1/5000
#  - 140s - loss: 4.2611 - acc: 0.0365 - val_loss: 4.1591 - val_acc: 0.0378
#
# Epoch 00001: val_acc improved from -inf to 0.03777, saving model to new_LSTM_best_model.h5
# Epoch 2/5000
#  - 132s - loss: 4.1591 - acc: 0.0397 - val_loss: 4.1575 - val_acc: 0.0401
#
# Epoch 00002: val_acc improved from 0.03777 to 0.04010, saving model to new_LSTM_best_model.h5
# Epoch 3/5000
#  - 135s - loss: 4.1582 - acc: 0.0394 - val_loss: 4.1578 - val_acc: 0.0401
#
# Epoch 00003: val_acc did not improve from 0.04010
# Epoch 4/5000
#  - 132s - loss: 4.1580 - acc: 0.0395 - val_loss: 4.1567 - val_acc: 0.0400
#
# Epoch 00004: val_acc did not improve from 0.04010
# Epoch 5/5000
#  - 134s - loss: 4.1576 - acc: 0.0397 - val_loss: 4.1564 - val_acc: 0.0401
#
# Epoch 00005: val_acc did not improve from 0.04010
# Epoch 6/5000
#  - 133s - loss: 4.1567 - acc: 0.0394 - val_loss: 4.1557 - val_acc: 0.0401
#
# Epoch 00006: val_acc did not improve from 0.04010
# Epoch 7/5000
#  - 134s - loss: 4.1564 - acc: 0.0389 - val_loss: 4.1552 - val_acc: 0.0401
#
# Epoch 00007: val_acc did not improve from 0.04010
# Epoch 8/5000
#  - 135s - loss: 4.1558 - acc: 0.0397 - val_loss: 4.1541 - val_acc: 0.0402
#
# Epoch 00008: val_acc improved from 0.04010 to 0.04018, saving model to new_LSTM_best_model.h5
# Epoch 9/5000
#  - 133s - loss: 4.1543 - acc: 0.0411 - val_loss: 4.1529 - val_acc: 0.0401
#
# Epoch 00009: val_acc did not improve from 0.04018
# Epoch 10/5000
#  - 132s - loss: 4.1531 - acc: 0.0410 - val_loss: 4.1510 - val_acc: 0.0506
#
# Epoch 00010: val_acc improved from 0.04018 to 0.05059, saving model to new_LSTM_best_model.h5
# Epoch 11/5000
#  - 135s - loss: 4.1500 - acc: 0.0441 - val_loss: 4.1458 - val_acc: 0.0511
#
# Epoch 00011: val_acc improved from 0.05059 to 0.05114, saving model to new_LSTM_best_model.h5
# Epoch 12/5000
#  - 133s - loss: 4.1380 - acc: 0.0482 - val_loss: 4.1198 - val_acc: 0.0545
#
# Epoch 00012: val_acc improved from 0.05114 to 0.05446, saving model to new_LSTM_best_model.h5
# Epoch 13/5000
#  - 133s - loss: 4.1022 - acc: 0.0586 - val_loss: 4.0824 - val_acc: 0.0623
#
# Epoch 00013: val_acc improved from 0.05446 to 0.06225, saving model to new_LSTM_best_model.h5
# Epoch 14/5000
#  - 133s - loss: 4.0665 - acc: 0.0649 - val_loss: 4.0379 - val_acc: 0.0689
#
# Epoch 00014: val_acc improved from 0.06225 to 0.06894, saving model to new_LSTM_best_model.h5
# Epoch 15/5000
#  - 133s - loss: 4.0228 - acc: 0.0696 - val_loss: 4.0269 - val_acc: 0.0717
#
# Epoch 00015: val_acc improved from 0.06894 to 0.07171, saving model to new_LSTM_best_model.h5
# Epoch 16/5000
#  - 133s - loss: 4.0008 - acc: 0.0729 - val_loss: 3.9844 - val_acc: 0.0780
#
# Epoch 00016: val_acc improved from 0.07171 to 0.07803, saving model to new_LSTM_best_model.h5
# Epoch 17/5000
#  - 133s - loss: 3.9662 - acc: 0.0778 - val_loss: 3.9639 - val_acc: 0.0836
#
# Epoch 00017: val_acc improved from 0.07803 to 0.08361, saving model to new_LSTM_best_model.h5
# Epoch 18/5000
#  - 133s - loss: 3.9386 - acc: 0.0812 - val_loss: 3.9390 - val_acc: 0.0858
#
# Epoch 00018: val_acc improved from 0.08361 to 0.08583, saving model to new_LSTM_best_model.h5
# Epoch 19/5000
#  - 133s - loss: 3.9075 - acc: 0.0876 - val_loss: 3.8889 - val_acc: 0.0951
#
# Epoch 00019: val_acc improved from 0.08583 to 0.09512, saving model to new_LSTM_best_model.h5
# Epoch 20/5000
#  - 133s - loss: 3.8766 - acc: 0.0951 - val_loss: 3.8662 - val_acc: 0.0991
#
# Epoch 00020: val_acc improved from 0.09512 to 0.09911, saving model to new_LSTM_best_model.h5
# Epoch 21/5000
#  - 135s - loss: 3.8478 - acc: 0.1013 - val_loss: 3.8406 - val_acc: 0.1011
#
# Epoch 00021: val_acc improved from 0.09911 to 0.10109, saving model to new_LSTM_best_model.h5
# Epoch 22/5000
#  - 134s - loss: 3.8185 - acc: 0.1073 - val_loss: 3.8266 - val_acc: 0.1058
#
# Epoch 00022: val_acc improved from 0.10109 to 0.10584, saving model to new_LSTM_best_model.h5
# Epoch 23/5000
#  - 133s - loss: 3.7912 - acc: 0.1112 - val_loss: 3.7906 - val_acc: 0.1170
#
# Epoch 00023: val_acc improved from 0.10584 to 0.11695, saving model to new_LSTM_best_model.h5
# Epoch 24/5000
#  - 133s - loss: 3.7633 - acc: 0.1174 - val_loss: 3.7858 - val_acc: 0.1117
#
# Epoch 00024: val_acc did not improve from 0.11695
# Epoch 25/5000
#  - 134s - loss: 3.7350 - acc: 0.1230 - val_loss: 3.7346 - val_acc: 0.1282
#
# Epoch 00025: val_acc improved from 0.11695 to 0.12822, saving model to new_LSTM_best_model.h5
# Epoch 26/5000
#  - 137s - loss: 3.7090 - acc: 0.1276 - val_loss: 3.7130 - val_acc: 0.1319
#
# Epoch 00026: val_acc improved from 0.12822 to 0.13186, saving model to new_LSTM_best_model.h5
# Epoch 27/5000
#  - 138s - loss: 3.6817 - acc: 0.1332 - val_loss: 3.6862 - val_acc: 0.1370
#
# Epoch 00027: val_acc improved from 0.13186 to 0.13700, saving model to new_LSTM_best_model.h5
# Epoch 28/5000
#  - 135s - loss: 3.6648 - acc: 0.1378 - val_loss: 3.6760 - val_acc: 0.1384
#
# Epoch 00028: val_acc improved from 0.13700 to 0.13839, saving model to new_LSTM_best_model.h5
# Epoch 29/5000
#  - 135s - loss: 3.6320 - acc: 0.1431 - val_loss: 3.6538 - val_acc: 0.1443
#
# Epoch 00029: val_acc improved from 0.13839 to 0.14432, saving model to new_LSTM_best_model.h5
# Epoch 30/5000
#  - 136s - loss: 3.6057 - acc: 0.1490 - val_loss: 3.6201 - val_acc: 0.1480
#
# Epoch 00030: val_acc improved from 0.14432 to 0.14800, saving model to new_LSTM_best_model.h5
# Epoch 31/5000
#  - 135s - loss: 3.5773 - acc: 0.1544 - val_loss: 3.6340 - val_acc: 0.1520
#
# Epoch 00031: val_acc improved from 0.14800 to 0.15203, saving model to new_LSTM_best_model.h5
# Epoch 32/5000
#  - 135s - loss: 3.5759 - acc: 0.1544 - val_loss: 3.5833 - val_acc: 0.1552
#
# Epoch 00032: val_acc improved from 0.15203 to 0.15516, saving model to new_LSTM_best_model.h5
# Epoch 33/5000
#  - 135s - loss: 3.5593 - acc: 0.1579 - val_loss: 3.5751 - val_acc: 0.1622
#
# Epoch 00033: val_acc improved from 0.15516 to 0.16224, saving model to new_LSTM_best_model.h5
# Epoch 34/5000
#  - 136s - loss: 3.5173 - acc: 0.1641 - val_loss: 3.5568 - val_acc: 0.1627
#
# Epoch 00034: val_acc improved from 0.16224 to 0.16271, saving model to new_LSTM_best_model.h5
# Epoch 35/5000
#  - 135s - loss: 3.5034 - acc: 0.1664 - val_loss: 3.5252 - val_acc: 0.1681
#
# Epoch 00035: val_acc improved from 0.16271 to 0.16813, saving model to new_LSTM_best_model.h5
# Epoch 36/5000
#  - 135s - loss: 3.4784 - acc: 0.1705 - val_loss: 3.5143 - val_acc: 0.1692
#
# Epoch 00036: val_acc improved from 0.16813 to 0.16920, saving model to new_LSTM_best_model.h5
# Epoch 37/5000
#  - 137s - loss: 3.4591 - acc: 0.1745 - val_loss: 3.4991 - val_acc: 0.1726
#
# Epoch 00037: val_acc improved from 0.16920 to 0.17260, saving model to new_LSTM_best_model.h5
# Epoch 38/5000
#  - 139s - loss: 3.4391 - acc: 0.1779 - val_loss: 3.4961 - val_acc: 0.1729
#
# Epoch 00038: val_acc improved from 0.17260 to 0.17288, saving model to new_LSTM_best_model.h5
# Epoch 39/5000
#  - 135s - loss: 3.4256 - acc: 0.1810 - val_loss: 3.4967 - val_acc: 0.1677
#
# Epoch 00039: val_acc did not improve from 0.17288
# Epoch 40/5000
#  - 135s - loss: 3.4013 - acc: 0.1837 - val_loss: 3.4536 - val_acc: 0.1803
#
# Epoch 00040: val_acc improved from 0.17288 to 0.18027, saving model to new_LSTM_best_model.h5
# Epoch 41/5000
#  - 137s - loss: 3.4068 - acc: 0.1859 - val_loss: 3.4489 - val_acc: 0.1799
#
# Epoch 00041: val_acc did not improve from 0.18027
# Epoch 42/5000
#  - 136s - loss: 3.3693 - acc: 0.1898 - val_loss: 3.4534 - val_acc: 0.1821
#
# Epoch 00042: val_acc improved from 0.18027 to 0.18209, saving model to new_LSTM_best_model.h5
# Epoch 43/5000
#  - 137s - loss: 3.3497 - acc: 0.1940 - val_loss: 3.4301 - val_acc: 0.1870
#
# Epoch 00043: val_acc improved from 0.18209 to 0.18700, saving model to new_LSTM_best_model.h5
# Epoch 44/5000
#  - 136s - loss: 3.3366 - acc: 0.1962 - val_loss: 3.4047 - val_acc: 0.1868
#
# Epoch 00044: val_acc did not improve from 0.18700
# Epoch 45/5000
#  - 136s - loss: 3.3082 - acc: 0.2013 - val_loss: 3.4199 - val_acc: 0.1877
#
# Epoch 00045: val_acc improved from 0.18700 to 0.18775, saving model to new_LSTM_best_model.h5
# Epoch 46/5000
#  - 136s - loss: 3.3010 - acc: 0.2039 - val_loss: 3.3870 - val_acc: 0.1950
#
# Epoch 00046: val_acc improved from 0.18775 to 0.19502, saving model to new_LSTM_best_model.h5
# Epoch 47/5000
#  - 137s - loss: 3.2851 - acc: 0.2059 - val_loss: 3.3897 - val_acc: 0.1921
#
# Epoch 00047: val_acc did not improve from 0.19502
# Epoch 48/5000
#  - 136s - loss: 3.2613 - acc: 0.2094 - val_loss: 3.3605 - val_acc: 0.1992
# Epoch 00048: val_acc improved from 0.19502 to 0.19922, saving model to new_LSTM_best_model.h5
# Epoch 49/5000
#  - 136s - loss: 3.2460 - acc: 0.2142 - val_loss: 3.3470 - val_acc: 0.2013
#
# Epoch 00049: val_acc improved from 0.19922 to 0.20131, saving model to new_LSTM_best_model.h5
# Epoch 50/5000
#  - 136s - loss: 3.2232 - acc: 0.2161 - val_loss: 3.3224 - val_acc: 0.2063
#
# Epoch 00050: val_acc improved from 0.20131 to 0.20630, saving model to new_LSTM_best_model.h5
# Epoch 51/5000
#  - 137s - loss: 3.2137 - acc: 0.2192 - val_loss: 3.3440 - val_acc: 0.2012
#
# Epoch 00051: val_acc did not improve from 0.20630
# Epoch 52/5000
#  - 136s - loss: 3.1964 - acc: 0.2225 - val_loss: 3.3118 - val_acc: 0.2084
#
# Epoch 00052: val_acc improved from 0.20630 to 0.20835, saving model to new_LSTM_best_model.h5
# Epoch 53/5000
#  - 136s - loss: 3.1785 - acc: 0.2263 - val_loss: 3.3481 - val_acc: 0.2049
#
# Epoch 00053: val_acc did not improve from 0.20835
# Epoch 54/5000
#  - 136s - loss: 3.1677 - acc: 0.2287 - val_loss: 3.3476 - val_acc: 0.2058
#
# Epoch 00054: val_acc did not improve from 0.20835
# Epoch 55/5000
#  - 137s - loss: 3.1472 - acc: 0.2320 - val_loss: 3.2766 - val_acc: 0.2156
#
# Epoch 00055: val_acc improved from 0.20835 to 0.21559, saving model to new_LSTM_best_model.h5
# Epoch 56/5000
#  - 136s - loss: 3.1224 - acc: 0.2381 - val_loss: 3.3264 - val_acc: 0.2129
#
# Epoch 00056: val_acc did not improve from 0.21559
# Epoch 57/5000
#  - 135s - loss: 3.1208 - acc: 0.2383 - val_loss: 3.2746 - val_acc: 0.2189
#
# Epoch 00057: val_acc improved from 0.21559 to 0.21887, saving model to new_LSTM_best_model.h5
# Epoch 58/5000
#  - 136s - loss: 3.0990 - acc: 0.2423 - val_loss: 3.2558 - val_acc: 0.2221
#
# Epoch 00058: val_acc improved from 0.21887 to 0.22208, saving model to new_LSTM_best_model.h5
# Epoch 59/5000
#  - 137s - loss: 3.0766 - acc: 0.2476 - val_loss: 3.2815 - val_acc: 0.2195
#
# Epoch 00059: val_acc did not improve from 0.22208
# Epoch 60/5000
#  - 137s - loss: 3.0705 - acc: 0.2484 - val_loss: 3.2531 - val_acc: 0.2226
#
# Epoch 00060: val_acc improved from 0.22208 to 0.22255, saving model to new_LSTM_best_model.h5
# Epoch 61/5000
#  - 136s - loss: 3.0624 - acc: 0.2508 - val_loss: 3.2428 - val_acc: 0.2271
#
# Epoch 00061: val_acc improved from 0.22255 to 0.22706, saving model to new_LSTM_best_model.h5
# Epoch 62/5000
#  - 136s - loss: 3.0614 - acc: 0.2524 - val_loss: 3.2198 - val_acc: 0.2309
#
# Epoch 00062: val_acc improved from 0.22706 to 0.23090, saving model to new_LSTM_best_model.h5
# Epoch 63/5000
#  - 136s - loss: 3.0230 - acc: 0.2589 - val_loss: 3.2155 - val_acc: 0.2312
#
# Epoch 00063: val_acc improved from 0.23090 to 0.23121, saving model to new_LSTM_best_model.h5
# Epoch 64/5000
#  - 136s - loss: 3.0088 - acc: 0.2625 - val_loss: 3.2411 - val_acc: 0.2283
#
# Epoch 00064: val_acc did not improve from 0.23121
# Epoch 65/5000
#  - 135s - loss: 3.0178 - acc: 0.2608 - val_loss: 3.2058 - val_acc: 0.2370
#
# Epoch 00065: val_acc improved from 0.23121 to 0.23703, saving model to new_LSTM_best_model.h5
# Epoch 66/5000
#  - 137s - loss: 2.9779 - acc: 0.2676 - val_loss: 3.2048 - val_acc: 0.2383
#
# Epoch 00066: val_acc improved from 0.23703 to 0.23833, saving model to new_LSTM_best_model.h5
# Epoch 67/5000
#  - 135s - loss: 2.9746 - acc: 0.2690 - val_loss: 3.2233 - val_acc: 0.2347
#
# Epoch 00067: val_acc did not improve from 0.23833
# Epoch 68/5000
#  - 135s - loss: 2.9643 - acc: 0.2711 - val_loss: 3.2478 - val_acc: 0.2337
#
# Epoch 00068: val_acc did not improve from 0.23833
# Epoch 69/5000
#  - 136s - loss: 2.9552 - acc: 0.2723 - val_loss: 3.2011 - val_acc: 0.2395
#
# Epoch 00069: val_acc improved from 0.23833 to 0.23952, saving model to new_LSTM_best_model.h5
# Epoch 70/5000
#  - 138s - loss: 2.9262 - acc: 0.2785 - val_loss: 3.1985 - val_acc: 0.2402
#
# Epoch 00070: val_acc improved from 0.23952 to 0.24019, saving model to new_LSTM_best_model.h5
# Epoch 71/5000
#  - 135s - loss: 2.9228 - acc: 0.2803 - val_loss: 3.1909 - val_acc: 0.2434
#
# Epoch 00071: val_acc improved from 0.24019 to 0.24340, saving model to new_LSTM_best_model.h5
# Epoch 72/5000
#  - 135s - loss: 2.9068 - acc: 0.2834 - val_loss: 3.2045 - val_acc: 0.2423
#
# Epoch 00072: val_acc did not improve from 0.24340
# Epoch 73/5000
#  - 135s - loss: 2.9155 - acc: 0.2813 - val_loss: 3.1865 - val_acc: 0.2425
#
# Epoch 00073: val_acc did not improve from 0.24340
# Epoch 74/5000
#  - 135s - loss: 2.8906 - acc: 0.2873 - val_loss: 3.1473 - val_acc: 0.2502
#
# Epoch 00074: val_acc improved from 0.24340 to 0.25024, saving model to new_LSTM_best_model.h5
# Epoch 75/5000
#  - 136s - loss: 2.8589 - acc: 0.2920 - val_loss: 3.1741 - val_acc: 0.2493
#
# Epoch 00075: val_acc did not improve from 0.25024
# Epoch 76/5000
#  - 135s - loss: 2.8586 - acc: 0.2931 - val_loss: 3.1975 - val_acc: 0.2427
#
# Epoch 00076: val_acc did not improve from 0.25024
# Epoch 77/5000
#  - 135s - loss: 2.8407 - acc: 0.2968 - val_loss: 3.1432 - val_acc: 0.2492
#
# Epoch 00077: val_acc did not improve from 0.25024
# Epoch 78/5000
#  - 135s - loss: 2.8501 - acc: 0.2944 - val_loss: 3.1862 - val_acc: 0.2476
#
# Epoch 00078: val_acc did not improve from 0.25024
# Epoch 79/5000
#  - 136s - loss: 2.8246 - acc: 0.2994 - val_loss: 3.2272 - val_acc: 0.2464
#
# Epoch 00079: val_acc did not improve from 0.25024
# Epoch 80/5000
#  - 135s - loss: 2.8259 - acc: 0.3003 - val_loss: 3.1413 - val_acc: 0.2534
#
# Epoch 00080: val_acc improved from 0.25024 to 0.25336, saving model to new_LSTM_best_model.h5
# Epoch 81/5000
#  - 136s - loss: 2.7884 - acc: 0.3069 - val_loss: 3.1541 - val_acc: 0.2538
#
# Epoch 00081: val_acc improved from 0.25336 to 0.25384, saving model to new_LSTM_best_model.h5
# Epoch 82/5000
#  - 134s - loss: 2.7839 - acc: 0.3090 - val_loss: 3.1481 - val_acc: 0.2534
#
# Epoch 00082: val_acc did not improve from 0.25384
# Epoch 83/5000
#  - 134s - loss: 2.7700 - acc: 0.3097 - val_loss: 3.1333 - val_acc: 0.2596
#
# Epoch 00083: val_acc improved from 0.25384 to 0.25961, saving model to new_LSTM_best_model.h5
# Epoch 84/5000
#  - 133s - loss: 2.7745 - acc: 0.3097 - val_loss: 3.1423 - val_acc: 0.2590
#
# Epoch 00084: val_acc did not improve from 0.25961
# Epoch 85/5000
#  - 133s - loss: 2.7557 - acc: 0.3128 - val_loss: 3.1478 - val_acc: 0.2560
#
# Epoch 00085: val_acc did not improve from 0.25961
# Epoch 86/5000
#  - 133s - loss: 2.7510 - acc: 0.3150 - val_loss: 3.1522 - val_acc: 0.2560
#
# Epoch 00086: val_acc did not improve from 0.25961
# Epoch 87/5000
#  - 133s - loss: 2.7295 - acc: 0.3186 - val_loss: 3.1582 - val_acc: 0.2562
#
# Epoch 00087: val_acc did not improve from 0.25961
# Epoch 88/5000
#  - 136s - loss: 2.7188 - acc: 0.3204 - val_loss: 3.2138 - val_acc: 0.2554
#
# Epoch 00088: val_acc did not improve from 0.25961
# Epoch 89/5000
#  - 133s - loss: 2.7081 - acc: 0.3245 - val_loss: 3.1607 - val_acc: 0.2584
#
# Epoch 00089: val_acc did not improve from 0.25961
# Epoch 90/5000
#  - 133s - loss: 2.6980 - acc: 0.3258 - val_loss: 3.2148 - val_acc: 0.2575
#
# Epoch 00090: val_acc did not improve from 0.25961
# Epoch 91/5000
#  - 133s - loss: 2.6999 - acc: 0.3253 - val_loss: 3.1652 - val_acc: 0.2613
#
# Epoch 00091: val_acc improved from 0.25961 to 0.26127, saving model to new_LSTM_best_model.h5
# Epoch 92/5000
#  - 133s - loss: 2.6769 - acc: 0.3294 - val_loss: 3.2031 - val_acc: 0.2610
#
# Epoch 00092: val_acc did not improve from 0.26127
# Epoch 93/5000
#  - 133s - loss: 2.6529 - acc: 0.3345 - val_loss: 3.1631 - val_acc: 0.2634
#
# Epoch 00093: val_acc improved from 0.26127 to 0.26345, saving model to new_LSTM_best_model.h5
# Epoch 94/5000
#  - 134s - loss: 2.6532 - acc: 0.3333 - val_loss: 3.2097 - val_acc: 0.2611
#
# Epoch 00094: val_acc did not improve from 0.26345
# Epoch 95/5000
#  - 132s - loss: 2.6361 - acc: 0.3374 - val_loss: 3.1557 - val_acc: 0.2662
#
# Epoch 00095: val_acc improved from 0.26345 to 0.26618, saving model to new_LSTM_best_model.h5
# Epoch 96/5000
#  - 134s - loss: 2.6344 - acc: 0.3384 - val_loss: 3.1853 - val_acc: 0.2642
#
# Epoch 00096: val_acc did not improve from 0.26618
# Epoch 97/5000
#  - 132s - loss: 2.6274 - acc: 0.3391 - val_loss: 3.1176 - val_acc: 0.2695
#
# Epoch 00097: val_acc improved from 0.26618 to 0.26946, saving model to new_LSTM_best_model.h5
# Epoch 98/5000
#  - 133s - loss: 2.6182 - acc: 0.3420 - val_loss: 3.2441 - val_acc: 0.2604
#
# Epoch 00098: val_acc did not improve from 0.26946
# Epoch 99/5000
#  - 132s - loss: 2.5940 - acc: 0.3463 - val_loss: 3.1916 - val_acc: 0.2669
#
# Epoch 00099: val_acc did not improve from 0.26946
# Epoch 100/5000
#  - 135s - loss: 2.5991 - acc: 0.3450 - val_loss: 3.1986 - val_acc: 0.2621
#
# Epoch 00100: val_acc did not improve from 0.26946
# Epoch 101/5000
#  - 132s - loss: 2.5766 - acc: 0.3493 - val_loss: 3.1586 - val_acc: 0.2685
#
# Epoch 00101: val_acc did not improve from 0.26946
# Epoch 102/5000
#  - 133s - loss: 2.5707 - acc: 0.3500 - val_loss: 3.2653 - val_acc: 0.2644
#
# Epoch 00102: val_acc did not improve from 0.26946
# Epoch 103/5000
#  - 133s - loss: 2.5577 - acc: 0.3524 - val_loss: 3.1557 - val_acc: 0.2693
#
# Epoch 00103: val_acc did not improve from 0.26946
# Epoch 104/5000
#  - 132s - loss: 2.5456 - acc: 0.3552 - val_loss: 3.2531 - val_acc: 0.2698
#
# Epoch 00104: val_acc improved from 0.26946 to 0.26981, saving model to new_LSTM_best_model.h5
# Epoch 105/5000
#  - 133s - loss: 2.5410 - acc: 0.3568 - val_loss: 3.1962 - val_acc: 0.2652
#
# Epoch 00105: val_acc did not improve from 0.26981
# Epoch 106/5000
#  - 132s - loss: 2.5439 - acc: 0.3557 - val_loss: 3.1669 - val_acc: 0.2704
#
# Epoch 00106: val_acc improved from 0.26981 to 0.27045, saving model to new_LSTM_best_model.h5
# Epoch 107/5000
#  - 133s - loss: 2.5080 - acc: 0.3631 - val_loss: 3.2644 - val_acc: 0.2611
#
# Epoch 00107: val_acc did not improve from 0.27045
# Epoch 108/5000
#  - 132s - loss: 2.5110 - acc: 0.3631 - val_loss: 3.2114 - val_acc: 0.2642
#
# Epoch 00108: val_acc did not improve from 0.27045
# Epoch 109/5000
#  - 133s - loss: 2.5246 - acc: 0.3585 - val_loss: 3.1372 - val_acc: 0.2657
#
# Epoch 00109: val_acc did not improve from 0.27045
# Epoch 110/5000
#  - 133s - loss: 2.5365 - acc: 0.3589 - val_loss: 3.1886 - val_acc: 0.2720
#
# Epoch 00110: val_acc improved from 0.27045 to 0.27203, saving model to new_LSTM_best_model.h5
# Epoch 111/5000
#  - 133s - loss: 2.4855 - acc: 0.3684 - val_loss: 3.2145 - val_acc: 0.2712
#
# Epoch 00111: val_acc did not improve from 0.27203
# Epoch 112/5000
#  - 133s - loss: 2.4645 - acc: 0.3717 - val_loss: 3.2930 - val_acc: 0.2642
#
# Epoch 00112: val_acc did not improve from 0.27203
# Epoch 113/5000
#  - 135s - loss: 2.4843 - acc: 0.3684 - val_loss: 3.2127 - val_acc: 0.2665
#
# Epoch 00113: val_acc did not improve from 0.27203
# Epoch 114/5000
#  - 134s - loss: 2.4929 - acc: 0.3662 - val_loss: 3.2433 - val_acc: 0.2724
#
# Epoch 00114: val_acc improved from 0.27203 to 0.27239, saving model to new_LSTM_best_model.h5
# Epoch 115/5000
#  - 134s - loss: 2.4402 - acc: 0.3765 - val_loss: 3.2210 - val_acc: 0.2723
#
# Epoch 00115: val_acc did not improve from 0.27239
# Epoch 116/5000
#  - 138s - loss: 2.4229 - acc: 0.3809 - val_loss: 3.1859 - val_acc: 0.2733
#
# Epoch 00116: val_acc improved from 0.27239 to 0.27326, saving model to new_LSTM_best_model.h5
# Epoch 117/5000
#  - 135s - loss: 2.4332 - acc: 0.3790 - val_loss: 3.1381 - val_acc: 0.2731
#
# Epoch 00117: val_acc did not improve from 0.27326
# Epoch 118/5000
#  - 135s - loss: 2.4418 - acc: 0.3775 - val_loss: 3.1838 - val_acc: 0.2740
#
# Epoch 00118: val_acc improved from 0.27326 to 0.27401, saving model to new_LSTM_best_model.h5
# Epoch 119/5000
#  - 136s - loss: 2.4487 - acc: 0.3748 - val_loss: 3.1969 - val_acc: 0.2758
#
# Epoch 00119: val_acc improved from 0.27401 to 0.27583, saving model to new_LSTM_best_model.h5
# Epoch 120/5000
#  - 135s - loss: 2.3897 - acc: 0.3866 - val_loss: 3.2695 - val_acc: 0.2718
#
# Epoch 00120: val_acc did not improve from 0.27583
# Epoch 121/5000
#  - 135s - loss: 2.3800 - acc: 0.3891 - val_loss: 3.1865 - val_acc: 0.2727
#
# Epoch 00121: val_acc did not improve from 0.27583
# Epoch 122/5000
#  - 135s - loss: 2.3875 - acc: 0.3883 - val_loss: 3.2234 - val_acc: 0.2730
#
# Epoch 00122: val_acc did not improve from 0.27583
# Epoch 123/5000
#  - 136s - loss: 2.3555 - acc: 0.3946 - val_loss: 3.3113 - val_acc: 0.2701
#
# Epoch 00123: val_acc did not improve from 0.27583
# Epoch 124/5000
#  - 135s - loss: 2.3658 - acc: 0.3933 - val_loss: 3.3010 - val_acc: 0.2724
#
# Epoch 00124: val_acc did not improve from 0.27583
# Epoch 125/5000
#  - 135s - loss: 2.3428 - acc: 0.3965 - val_loss: 3.2982 - val_acc: 0.2691
#
# Epoch 00125: val_acc did not improve from 0.27583
# Epoch 126/5000
#  - 135s - loss: 2.3554 - acc: 0.3936 - val_loss: 3.2552 - val_acc: 0.2720
#
# Epoch 00126: val_acc did not improve from 0.27583
# Epoch 127/5000
#  - 135s - loss: 2.3354 - acc: 0.3985 - val_loss: 3.2294 - val_acc: 0.2754
#
# Epoch 00127: val_acc did not improve from 0.27583
# Epoch 128/5000
#  - 135s - loss: 2.3107 - acc: 0.4032 - val_loss: 3.3066 - val_acc: 0.2737
#
# Epoch 00128: val_acc did not improve from 0.27583
# Epoch 129/5000
#  - 135s - loss: 2.3189 - acc: 0.4017 - val_loss: 3.2217 - val_acc: 0.2720
#
# Epoch 00129: val_acc did not improve from 0.27583
# Epoch 130/5000
#  - 135s - loss: 2.3326 - acc: 0.3989 - val_loss: 3.2966 - val_acc: 0.2708
#
# Epoch 00130: val_acc did not improve from 0.27583
# Epoch 131/5000
#  - 135s - loss: 2.3269 - acc: 0.4018 - val_loss: 3.3244 - val_acc: 0.2691
#
# Epoch 00131: val_acc did not improve from 0.27583
# Epoch 132/5000
#  - 135s - loss: 2.3138 - acc: 0.4032 - val_loss: 3.3305 - val_acc: 0.2638
#
# Epoch 00132: val_acc did not improve from 0.27583
# Epoch 133/5000
#  - 136s - loss: 2.2951 - acc: 0.4061 - val_loss: 3.3286 - val_acc: 0.2683
#
# Epoch 00133: val_acc did not improve from 0.27583
# Epoch 134/5000
#  - 135s - loss: 2.2732 - acc: 0.4117 - val_loss: 3.3802 - val_acc: 0.2675
#
# Epoch 00134: val_acc did not improve from 0.27583
# Epoch 135/5000
#  - 134s - loss: 2.2821 - acc: 0.4099 - val_loss: 3.2795 - val_acc: 0.2666
#
# Epoch 00135: val_acc did not improve from 0.27583
# Epoch 136/5000
#  - 135s - loss: 2.2512 - acc: 0.4164 - val_loss: 3.4378 - val_acc: 0.2650
#
# Epoch 00136: val_acc did not improve from 0.27583
# Epoch 137/5000
#  - 135s - loss: 2.2561 - acc: 0.4154 - val_loss: 3.3554 - val_acc: 0.2685
#
# Epoch 00137: val_acc did not improve from 0.27583
# Epoch 138/5000
#  - 135s - loss: 2.2528 - acc: 0.4156 - val_loss: 3.3802 - val_acc: 0.2697
#
# Epoch 00138: val_acc did not improve from 0.27583
# Epoch 139/5000
#  - 136s - loss: 2.2227 - acc: 0.4238 - val_loss: 3.3996 - val_acc: 0.2648
#
# Epoch 00139: val_acc did not improve from 0.27583
# Epoch 140/5000
#  - 135s - loss: 2.2506 - acc: 0.4163 - val_loss: 3.4192 - val_acc: 0.2692
#
# Epoch 00140: val_acc did not improve from 0.27583
# Epoch 141/5000
#  - 135s - loss: 2.2387 - acc: 0.4189 - val_loss: 3.4088 - val_acc: 0.2712
#
# Epoch 00141: val_acc did not improve from 0.27583
# Epoch 142/5000
#  - 135s - loss: 2.2161 - acc: 0.4252 - val_loss: 3.2115 - val_acc: 0.2708
#
# Epoch 00142: val_acc did not improve from 0.27583
# Epoch 143/5000
#  - 135s - loss: 2.2356 - acc: 0.4207 - val_loss: 3.3724 - val_acc: 0.2709
#
# Epoch 00143: val_acc did not improve from 0.27583
# Epoch 144/5000
#  - 135s - loss: 2.1923 - acc: 0.4289 - val_loss: 3.3682 - val_acc: 0.2690
#
# Epoch 00144: val_acc did not improve from 0.27583
# Epoch 145/5000
#  - 135s - loss: 2.2111 - acc: 0.4239 - val_loss: 3.5020 - val_acc: 0.2663
#
# Epoch 00145: val_acc did not improve from 0.27583
# Epoch 146/5000
#  - 134s - loss: 2.1919 - acc: 0.4300 - val_loss: 3.5325 - val_acc: 0.2653
#
# Epoch 00146: val_acc did not improve from 0.27583
# Epoch 147/5000
#  - 135s - loss: 2.2057 - acc: 0.4259 - val_loss: 3.5604 - val_acc: 0.2612
#
# Epoch 00147: val_acc did not improve from 0.27583
# Epoch 148/5000
#  - 134s - loss: 2.1796 - acc: 0.4318 - val_loss: 3.4894 - val_acc: 0.2641
#
# Epoch 00148: val_acc did not improve from 0.27583
# Epoch 149/5000
#  - 134s - loss: 2.1525 - acc: 0.4395 - val_loss: 3.4166 - val_acc: 0.2727
#
# Epoch 00149: val_acc did not improve from 0.27583
# Epoch 150/5000
#  - 134s - loss: 2.1920 - acc: 0.4301 - val_loss: 3.4851 - val_acc: 0.2665
#
# Epoch 00150: val_acc did not improve from 0.27583
# Epoch 151/5000
#  - 134s - loss: 2.1554 - acc: 0.4378 - val_loss: 3.5148 - val_acc: 0.2671
#
# Epoch 00151: val_acc did not improve from 0.27583
# Epoch 152/5000
#  - 134s - loss: 2.1721 - acc: 0.4338 - val_loss: 3.3567 - val_acc: 0.2712
#
# Epoch 00152: val_acc did not improve from 0.27583
# Epoch 153/5000
#  - 134s - loss: 2.1647 - acc: 0.4339 - val_loss: 3.4405 - val_acc: 0.2725
#
# Epoch 00153: val_acc did not improve from 0.27583
# Epoch 154/5000
#  - 134s - loss: 2.1314 - acc: 0.4445 - val_loss: 3.5808 - val_acc: 0.2607
#
# Epoch 00154: val_acc did not improve from 0.27583
# Epoch 155/5000
#  - 136s - loss: 2.1216 - acc: 0.4461 - val_loss: 3.5345 - val_acc: 0.2641
#
# Epoch 00155: val_acc did not improve from 0.27583
# Epoch 156/5000
#  - 135s - loss: 2.1008 - acc: 0.4493 - val_loss: 3.5096 - val_acc: 0.2678
# Epoch 00156: val_acc did not improve from 0.27583
# Epoch 157/5000
#  - 135s - loss: 2.1045 - acc: 0.4491 - val_loss: 3.5367 - val_acc: 0.2659
#
# Epoch 00157: val_acc did not improve from 0.27583
# Epoch 158/5000
#  - 134s - loss: 2.1086 - acc: 0.4499 - val_loss: 3.6489 - val_acc: 0.2581
#
# Epoch 00158: val_acc did not improve from 0.27583
# Epoch 159/5000
#  - 135s - loss: 2.0976 - acc: 0.4512 - val_loss: 3.5274 - val_acc: 0.2706
#
# Epoch 00159: val_acc did not improve from 0.27583
# Epoch 160/5000
#  - 135s - loss: 2.0566 - acc: 0.4604 - val_loss: 3.5959 - val_acc: 0.2674
#
# Epoch 00160: val_acc did not improve from 0.27583
# Epoch 161/5000
#  - 134s - loss: 2.0565 - acc: 0.4604 - val_loss: 3.5179 - val_acc: 0.2645
#
# Epoch 00161: val_acc did not improve from 0.27583
# Epoch 162/5000
#  - 134s - loss: 2.0795 - acc: 0.4538 - val_loss: 3.5374 - val_acc: 0.2692
#
# Epoch 00162: val_acc did not improve from 0.27583
# Epoch 163/5000
#  - 134s - loss: 2.0415 - acc: 0.4642 - val_loss: 3.7536 - val_acc: 0.2652
#
# Epoch 00163: val_acc did not improve from 0.27583
# Epoch 164/5000
#  - 134s - loss: 2.0647 - acc: 0.4581 - val_loss: 3.5974 - val_acc: 0.2684
#
# Epoch 00164: val_acc did not improve from 0.27583
# Epoch 165/5000
#  - 136s - loss: 2.0510 - acc: 0.4601 - val_loss: 3.6866 - val_acc: 0.2620
#
# Epoch 00165: val_acc did not improve from 0.27583
# Epoch 166/5000
#  - 134s - loss: 2.0381 - acc: 0.4636 - val_loss: 3.7405 - val_acc: 0.2640
#
# Epoch 00166: val_acc did not improve from 0.27583
# Epoch 167/5000
#  - 137s - loss: 2.0365 - acc: 0.4638 - val_loss: 3.8240 - val_acc: 0.2591
#
# Epoch 00167: val_acc did not improve from 0.27583
# Epoch 168/5000
#  - 135s - loss: 2.0549 - acc: 0.4603 - val_loss: 3.6874 - val_acc: 0.2657
#
# Epoch 00168: val_acc did not improve from 0.27583
# Epoch 169/5000
#  - 134s - loss: 2.0196 - acc: 0.4700 - val_loss: 3.8269 - val_acc: 0.2453
#
# Epoch 00169: val_acc did not improve from 0.27583
# Epoch 00169: early stopping
# Time elapsed during training: 22778.76155090332
# Accuracy on training set: 0.39280558466984394
# Accuracy on held-out test set: 0.2758266097136529

# %%
def plotFittingAccuracy(history):
    
    plt.plot(history.history['acc'], label='train set')
    plt.plot(history.history['val_acc'], label='test set')
    
    plt.title("Accuracy during training")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend()
    plt.show()
    
plotFittingAccuracy(history)

# %% [markdown]
# # Evaluation

# %%
def reveseOneHot(prediction_output):
    integer_encode = onehot_encoder.inverse_transform(prediction_output).flatten().astype(int)
    return integer_encoder.inverse_transform(integer_encode)

# %%
onehot_pred = classifier.predict(vectors_test)
y_pred = reveseOneHot(onehot_pred)

# %%
def plotConfusionMatrix(confusionMatrix, classes):
    
    confusionMatrix = confusionMatrix.astype('float') / confusionMatrix.sum(axis=1)[:, np.newaxis]
    
    heatmap_df = pd.DataFrame(confusionMatrix, index=classes, columns=classes)
    
    fig, ax = plt.subplots(figsize=(16,13))
    sns.heatmap(heatmap_df, xticklabels=True,yticklabels=True, ax=ax, vmin=0,vmax=1)
    ax.set_aspect("equal")
    plt.title("Confusion Matrix", fontsize=20)
    plt.ylabel("true category", fontsize=15)
    plt.xlabel("predicted category", fontsize=15)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

category_list = unique_labels(y_test, y_pred)

cMatrix = confusion_matrix(y_test, y_pred, labels=category_list)

plotConfusionMatrix(cMatrix, category_list)

# %%
def precisionFromConfusionMatrix(confusionMatrix):
    
    truePos = np.diagonal(confusionMatrix)
    falsePos = np.asarray(confusionMatrix.sum(axis=0)) - truePos
    
    precision = truePos / (truePos + falsePos)
    precision = precision[~np.isnan(precision)]
    
    return precision.mean()

precision = precisionFromConfusionMatrix(cMatrix)
print("Average multiclass precision: {}".format(precision))
# Out:
# Average multiclass precision: 0.29306746491946684
