# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare the data

# %% [markdown]
# Basic data cleaning includes deleting the puctuation marks in the titles, and convert text into lower case.

# %%
import string

titles = pd.read_csv("./data/medium_post_titles.csv")
titles.drop(columns=["subtitle", "subtitle_truncated_flag"], inplace=True)

titles.title = titles.title.str.replace('[{}]'.format(string.punctuation), '').str.lower()
titles.title = titles.title.str.replace('‘', '')
titles.title = titles.title.str.replace('’', '')
titles.title = titles.title.str.replace('“', '')
titles.title = titles.title.str.replace('”', '')
titles.title = titles.title.str.replace('—', '')

titles.head()
# Out:
#                   category                                              title
# 0                     work  21 conversations  a fun and easy game for team...
# 1             spirituality                         biblical porn at mars hill
# 2                  lgbtqia                        cisgender is that a disease
# 3                 equality  call me nat love black cowboys and the frontie...
# 4  artificial-intelligence              can i train my model on your computer

# %% [markdown]
# In the original data, many categories are highly ralated. 59 categories are regrouped, forming larger categories. There are eventually 50 categories in total.

# %%
related_categories = pd.read_csv("related_categories.csv")
related_categories
# Out:
#                    original                     grouped
# 0             accessibility                equal_rights
# 1                 addiction         substance_addiction
# 2       android-development                 it_industry
# 3                       art             cultural_topics
# 4   artificial-intelligence              datascience_ai
# 5              basic-income            political_topics
# 6                blockchain             finance_economy
# 7                  business          business_marketing
# 8            cryptocurrency             finance_economy
# 9             cybersecurity                    security
# 10             data-science              datascience_ai
# 11                   design                   ux_design
# 12             digital-life                        tech
# 13               disability                equal_rights
# 14                  economy             finance_economy
# 15            election-2020            political_topics
# 16                 equality                equal_rights
# 17                   family                    domestic
# 18                  fiction                  literature
# 19                     film             cultural_topics
# 20              freelancing                        work
# 21                  gadgets                        tech
# 22              gun-control            political_topics
# 23              immigration            political_topics
# 24          ios-development                 it_industry
# 25               javascript                 it_industry
# 26                  justice            political_topics
# 27                  lgbtqia                equal_rights
# 28         machine-learning              datascience_ai
# 29                marketing          business_marketing
# 30            mental-health  mental_health_neuroscience
# 31              mindfulness  mental_health_neuroscience
# 32                    money             finance_economy
# 33                    music             cultural_topics
# 34             neuroscience  mental_health_neuroscience
# 35                parenting                    domestic
# 36                   poetry                  literature
# 37                 politics            political_topics
# 38                  privacy                    security
# 39       product-management                 it_industry
# 40             productivity                        work
# 41              programming                 it_industry
# 42             psychedelics         substance_addiction
# 43               psychology  mental_health_neuroscience
# 44                     race                equal_rights
# 45            relationships                    domestic
# 46                 religion       religion_spirituality
# 47        self-driving-cars                        tech
# 48                sexuality                equal_rights
# 49     software-engineering                 it_industry
# 50             spirituality       religion_spirituality
# 51                 startups          business_marketing
# 52               technology                        tech
# 53                       tv             cultural_topics
# 54                       ux                   ux_design
# 55          venture-capital             finance_economy
# 56            visual-design                   ux_design
# 57                    women                equal_rights
# 58                     work                work_related

# %%
for i in related_categories.index:
    titles.category = titles.category.replace(*related_categories.loc[i])
    
titles.head()
# Out:
#                 category                                              title
# 0           work_related  21 conversations  a fun and easy game for team...
# 1  religion_spirituality                         biblical porn at mars hill
# 2           equal_rights                        cisgender is that a disease
# 3           equal_rights  call me nat love black cowboys and the frontie...
# 4         datascience_ai              can i train my model on your computer

# %% [markdown]
# Hold out 20% of data as the test set.

# %%
from sklearn.model_selection import train_test_split

titles_train, titles_test = train_test_split(titles, train_size=0.8, stratify=titles.category.values)

X_train = titles_train.title.values
X_test = titles_test.title.values

y_train = titles_train.category.values
y_test = titles_test.category.values

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The theme labels were converted to one hot representations.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

integer_encoder = LabelEncoder()
integer_train = integer_encoder.fit_transform(y_train).reshape((-1, 1))
integer_test = integer_encoder.transform(y_test).reshape((-1, 1))

onehot_encoder = OneHotEncoder(sparse=False)
onehot_train = onehot_encoder.fit_transform(integer_train)
onehot_test = onehot_encoder.transform(integer_test)

# %% [markdown]
# # Naive Bayess

# %% [markdown]
# Use TF-IDF to perform bag-of-words vectorization.

# %% [markdown]
# We adopted the Penn Treebank Tokenizer. Terms that appear less than twice or occur in more than 10% of the docuemnts are rejected. Typically, with TF-IDF vectorization, we can still use a multinomial naive Bayess classifier. Let's take a look at a naive Bayess classifer with Lapalace smoohing at alpha = 0.1.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import TreebankWordTokenizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

tokenizer = TreebankWordTokenizer()
vectorizer = TfidfVectorizer(tokenizer=tokenizer.tokenize, ngram_range=(1, 1), stop_words='english', min_df=2, max_df=0.1)

NBclassifier = MultinomialNB(alpha=0.1)

classifierNB = Pipeline([("TfIdf", vectorizer), ("NaiveBayess", NBclassifier)])
classifierNB.fit(X_train, y_train)

accuracyNB = classifierNB.score(X_test, y_test)
print("accuracy = {}".format(accuracyNB))
# Out:
# accuracy = 0.44280968201233983

# %% [markdown]
# # Multilayer Perceptron Network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from time import time
from keras.models import load_model

XMatrix_train = vectorizer.fit_transform(X_train)
vocabulary = np.array(vectorizer.get_feature_names())
vocabularySize = vocabulary.size

XMatrix_test = vectorizer.transform(X_test)

layer1 = Dense(256, activation="relu", input_dim=vocabularySize)
layer2 = Dense(256, activation="relu")
outputLayer = Dense(50, activation="softmax")
classifierMLP = Sequential([layer1, layer2, outputLayer])
classifierMLP.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["acc"])

early_stopping = EarlyStopping(monitor="val_acc", mode="max", patience=50, verbose=2)
best_model_saving = ModelCheckpoint("MLP_best_model.h5", monitor="val_acc", mode="max", save_best_only=True, verbose=2)

start_time = time()
history = classifierMLP.fit(XMatrix_train,onehot_train, epochs=5000, batch_size=2048, validation_data=(XMatrix_test,onehot_test), callbacks=[early_stopping, best_model_saving], verbose=2)
end_time = time()
print("Time elapsed during training: {}".format(end_time - start_time))

classifierMLP = load_model("MLP_best_model.h5")
_, train_accuracy = classifierMLP.evaluate(XMatrix_train, onehot_train, verbose=0)
print("Accuracy on training set: {}".format(train_accuracy))
_, test_accuracy = classifierMLP.evaluate(XMatrix_test, onehot_test, verbose=0)
print("Accuracy on held-out test set: {}".format(test_accuracy))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 101134 samples, validate on 25284 samples
# Epoch 1/5000
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Users/ZhaojieYao/opt/anaconda3/envs/Springboard/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 21s - loss: 3.5155 - acc: 0.1097 - val_loss: 3.0885 - val_acc: 0.2766
#
# Epoch 00001: val_acc improved from -inf to 0.27658, saving model to MLP_best_model.h5
# Epoch 2/5000
#  - 21s - loss: 2.5749 - acc: 0.4056 - val_loss: 2.2730 - val_acc: 0.4344
#
# Epoch 00002: val_acc improved from 0.27658 to 0.43442, saving model to MLP_best_model.h5
# Epoch 3/5000
#  - 20s - loss: 1.8542 - acc: 0.5386 - val_loss: 2.0379 - val_acc: 0.4849
#
# Epoch 00003: val_acc improved from 0.43442 to 0.48489, saving model to MLP_best_model.h5
# Epoch 4/5000
#  - 20s - loss: 1.4563 - acc: 0.6265 - val_loss: 2.0181 - val_acc: 0.4900
#
# Epoch 00004: val_acc improved from 0.48489 to 0.48995, saving model to MLP_best_model.h5
# Epoch 5/5000
#  - 20s - loss: 1.2116 - acc: 0.6832 - val_loss: 2.0805 - val_acc: 0.4875
#
# Epoch 00005: val_acc did not improve from 0.48995
# Epoch 6/5000
#  - 20s - loss: 1.0399 - acc: 0.7250 - val_loss: 2.1744 - val_acc: 0.4809
#
# Epoch 00006: val_acc did not improve from 0.48995
# Epoch 7/5000
#  - 20s - loss: 0.9140 - acc: 0.7556 - val_loss: 2.2830 - val_acc: 0.4726
#
# Epoch 00007: val_acc did not improve from 0.48995
# Epoch 8/5000
#  - 20s - loss: 0.8146 - acc: 0.7815 - val_loss: 2.3914 - val_acc: 0.4644
#
# Epoch 00008: val_acc did not improve from 0.48995
# Epoch 9/5000
#  - 20s - loss: 0.7358 - acc: 0.7998 - val_loss: 2.5039 - val_acc: 0.4587
#
# Epoch 00009: val_acc did not improve from 0.48995
# Epoch 10/5000
#  - 20s - loss: 0.6727 - acc: 0.8161 - val_loss: 2.6155 - val_acc: 0.4516
#
# Epoch 00010: val_acc did not improve from 0.48995
# Epoch 11/5000
#  - 20s - loss: 0.6188 - acc: 0.8296 - val_loss: 2.7296 - val_acc: 0.4468
#
# Epoch 00011: val_acc did not improve from 0.48995
# Epoch 12/5000
#  - 20s - loss: 0.5722 - acc: 0.8420 - val_loss: 2.8392 - val_acc: 0.4414
#
# Epoch 00012: val_acc did not improve from 0.48995
# Epoch 13/5000
#  - 20s - loss: 0.5312 - acc: 0.8527 - val_loss: 2.9453 - val_acc: 0.4380
#
# Epoch 00013: val_acc did not improve from 0.48995
# Epoch 14/5000
#  - 20s - loss: 0.4963 - acc: 0.8613 - val_loss: 3.0469 - val_acc: 0.4337
#
# Epoch 00014: val_acc did not improve from 0.48995
# Epoch 15/5000
#  - 20s - loss: 0.4646 - acc: 0.8708 - val_loss: 3.1423 - val_acc: 0.4311
#
# Epoch 00015: val_acc did not improve from 0.48995
# Epoch 16/5000
#  - 20s - loss: 0.4357 - acc: 0.8791 - val_loss: 3.2466 - val_acc: 0.4279
#
# Epoch 00016: val_acc did not improve from 0.48995
# Epoch 17/5000
#  - 20s - loss: 0.4092 - acc: 0.8859 - val_loss: 3.3538 - val_acc: 0.4265
#
# Epoch 00017: val_acc did not improve from 0.48995
# Epoch 18/5000
#  - 20s - loss: 0.3848 - acc: 0.8933 - val_loss: 3.4406 - val_acc: 0.4247
#
# Epoch 00018: val_acc did not improve from 0.48995
# Epoch 19/5000
#  - 20s - loss: 0.3620 - acc: 0.8999 - val_loss: 3.5394 - val_acc: 0.4210
#
# Epoch 00019: val_acc did not improve from 0.48995
# Epoch 20/5000
#  - 20s - loss: 0.3408 - acc: 0.9062 - val_loss: 3.6354 - val_acc: 0.4206
#
# Epoch 00020: val_acc did not improve from 0.48995
# Epoch 21/5000
#  - 20s - loss: 0.3208 - acc: 0.9119 - val_loss: 3.7211 - val_acc: 0.4175
#
# Epoch 00021: val_acc did not improve from 0.48995
# Epoch 22/5000
#  - 21s - loss: 0.3026 - acc: 0.9171 - val_loss: 3.8153 - val_acc: 0.4170
#
# Epoch 00022: val_acc did not improve from 0.48995
# Epoch 23/5000
#  - 20s - loss: 0.2859 - acc: 0.9229 - val_loss: 3.8937 - val_acc: 0.4146
#
# Epoch 00023: val_acc did not improve from 0.48995
# Epoch 24/5000
#  - 23s - loss: 0.2697 - acc: 0.9271 - val_loss: 3.9896 - val_acc: 0.4143
#
# Epoch 00024: val_acc did not improve from 0.48995
# Epoch 25/5000
#  - 24s - loss: 0.2551 - acc: 0.9314 - val_loss: 4.0608 - val_acc: 0.4124
#
# Epoch 00025: val_acc did not improve from 0.48995
# Epoch 26/5000
#  - 21s - loss: 0.2411 - acc: 0.9355 - val_loss: 4.1375 - val_acc: 0.4120
#
# Epoch 00026: val_acc did not improve from 0.48995
# Epoch 27/5000
#  - 20s - loss: 0.2282 - acc: 0.9388 - val_loss: 4.2166 - val_acc: 0.4102
#
# Epoch 00027: val_acc did not improve from 0.48995
# Epoch 28/5000
#  - 20s - loss: 0.2155 - acc: 0.9428 - val_loss: 4.2902 - val_acc: 0.4106
#
# Epoch 00028: val_acc did not improve from 0.48995
# Epoch 29/5000
#  - 20s - loss: 0.2049 - acc: 0.9457 - val_loss: 4.3639 - val_acc: 0.4106
#
# Epoch 00029: val_acc did not improve from 0.48995
# Epoch 30/5000
#  - 20s - loss: 0.1939 - acc: 0.9489 - val_loss: 4.4257 - val_acc: 0.4090
#
# Epoch 00030: val_acc did not improve from 0.48995
# Epoch 31/5000
#  - 21s - loss: 0.1847 - acc: 0.9517 - val_loss: 4.4860 - val_acc: 0.4077
#
# Epoch 00031: val_acc did not improve from 0.48995
# Epoch 32/5000
#  - 20s - loss: 0.1770 - acc: 0.9536 - val_loss: 4.5597 - val_acc: 0.4092
#
# Epoch 00032: val_acc did not improve from 0.48995
# Epoch 33/5000
#  - 20s - loss: 0.1678 - acc: 0.9560 - val_loss: 4.6215 - val_acc: 0.4071
#
# Epoch 00033: val_acc did not improve from 0.48995
# Epoch 34/5000
#  - 20s - loss: 0.1607 - acc: 0.9577 - val_loss: 4.6763 - val_acc: 0.4079
#
# Epoch 00034: val_acc did not improve from 0.48995
# Epoch 35/5000
#  - 20s - loss: 0.1530 - acc: 0.9597 - val_loss: 4.7305 - val_acc: 0.4063
#
# Epoch 00035: val_acc did not improve from 0.48995
# Epoch 36/5000
#  - 21s - loss: 0.1473 - acc: 0.9615 - val_loss: 4.7839 - val_acc: 0.4063
#
# Epoch 00036: val_acc did not improve from 0.48995
# Epoch 37/5000
#  - 20s - loss: 0.1418 - acc: 0.9629 - val_loss: 4.8328 - val_acc: 0.4063
#
# Epoch 00037: val_acc did not improve from 0.48995
# Epoch 38/5000
#  - 20s - loss: 0.1367 - acc: 0.9640 - val_loss: 4.8839 - val_acc: 0.4062
#
# Epoch 00038: val_acc did not improve from 0.48995
# Epoch 39/5000
#  - 20s - loss: 0.1321 - acc: 0.9650 - val_loss: 4.9280 - val_acc: 0.4058
#
# Epoch 00039: val_acc did not improve from 0.48995
# Epoch 40/5000
#  - 20s - loss: 0.1277 - acc: 0.9659 - val_loss: 4.9798 - val_acc: 0.4034
#
# Epoch 00040: val_acc did not improve from 0.48995
# Epoch 41/5000
#  - 21s - loss: 0.1242 - acc: 0.9670 - val_loss: 5.0109 - val_acc: 0.4030
#
# Epoch 00041: val_acc did not improve from 0.48995
# Epoch 42/5000
#  - 20s - loss: 0.1204 - acc: 0.9683 - val_loss: 5.0575 - val_acc: 0.4037
#
# Epoch 00042: val_acc did not improve from 0.48995
# Epoch 43/5000
#  - 21s - loss: 0.1168 - acc: 0.9686 - val_loss: 5.0912 - val_acc: 0.4040
#
# Epoch 00043: val_acc did not improve from 0.48995
# Epoch 44/5000
#  - 22s - loss: 0.1128 - acc: 0.9697 - val_loss: 5.1259 - val_acc: 0.4053
#
# Epoch 00044: val_acc did not improve from 0.48995
# Epoch 45/5000
#  - 22s - loss: 0.1110 - acc: 0.9699 - val_loss: 5.1605 - val_acc: 0.4052
#
# Epoch 00045: val_acc did not improve from 0.48995
# Epoch 46/5000
#  - 21s - loss: 0.1094 - acc: 0.9705 - val_loss: 5.1992 - val_acc: 0.4024
#
# Epoch 00046: val_acc did not improve from 0.48995
# Epoch 47/5000
#  - 20s - loss: 0.1061 - acc: 0.9708 - val_loss: 5.2320 - val_acc: 0.4035
#
# Epoch 00047: val_acc did not improve from 0.48995
# Epoch 48/5000
#  - 20s - loss: 0.1036 - acc: 0.9716 - val_loss: 5.2604 - val_acc: 0.4031
#
# Epoch 00048: val_acc did not improve from 0.48995
# Epoch 49/5000
#  - 20s - loss: 0.1011 - acc: 0.9721 - val_loss: 5.2947 - val_acc: 0.4039
#
# Epoch 00049: val_acc did not improve from 0.48995
# Epoch 50/5000
#  - 20s - loss: 0.1000 - acc: 0.9719 - val_loss: 5.3073 - val_acc: 0.4045
#
# Epoch 00050: val_acc did not improve from 0.48995
# Epoch 51/5000
#  - 20s - loss: 0.0986 - acc: 0.9723 - val_loss: 5.3402 - val_acc: 0.4028
#
# Epoch 00051: val_acc did not improve from 0.48995
# Epoch 52/5000
#  - 20s - loss: 0.0972 - acc: 0.9725 - val_loss: 5.3679 - val_acc: 0.4033
#
# Epoch 00052: val_acc did not improve from 0.48995
# Epoch 53/5000
#  - 20s - loss: 0.0946 - acc: 0.9729 - val_loss: 5.3894 - val_acc: 0.4026
#
# Epoch 00053: val_acc did not improve from 0.48995
# Epoch 54/5000
#  - 20s - loss: 0.0937 - acc: 0.9732 - val_loss: 5.4034 - val_acc: 0.4027
#
# Epoch 00054: val_acc did not improve from 0.48995
# Epoch 00054: early stopping
# Time elapsed during training: 1098.2961893081665
# Accuracy on training set: 0.6920026894998793
# Accuracy on held-out test set: 0.48995412118335707

# %%
def plotFittingAccuracy(history):
    
    plt.plot(history.history['acc'], label='train set')
    plt.plot(history.history['val_acc'], label='test set')
    
    plt.title("Accuracy during training")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend()
    plt.show()
    
plotFittingAccuracy(history)

# %% [markdown]
# # Precision-recall

# %%
probabilityNB = classifierNB.predict_proba(X_test)
classListNB = classifierNB.classes_
realLabelNB = np.equal(np.repeat(np.reshape(y_test, (-1, 1)), len(classListNB), axis=1), np.repeat(np.reshape(classListNB, (1, -1)), len(y_test), axis=0))

probabilityMLP = classifierMLP.predict_proba(XMatrix_test)
classListMLP = integer_encoder.classes_
realLabelMLP = np.equal(np.repeat(np.reshape(y_test, (-1, 1)), len(classListMLP), axis=1), np.repeat(np.reshape(classListMLP, (1, -1)), len(y_test), axis=0))


thresholds = np.arange(0, 1.001, 0.001)

correctSuggestionRateNB = np.zeros(len(thresholds))
correctSuggestionRateMLP = np.zeros(len(thresholds))

for i, threshold in enumerate(thresholds):
    
    predictedLabelNB = probabilityNB >= threshold
    correctSuggestionRateNB[i] = np.any((predictedLabelNB & realLabelNB), axis=1).mean()
    
    predictedLabelMLP = probabilityMLP >= threshold
    correctSuggestionRateMLP[i] = np.any((predictedLabelMLP & realLabelMLP), axis=1).mean()

# %%
plt.figure(figsize=(9,9))

plt.plot(thresholds, correctSuggestionRateNB, label="naive Bayes")
plt.plot(thresholds, correctSuggestionRateMLP, label="multilayer perceptron network")

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.gca().set_aspect('equal')
plt.legend(loc="upper right")
plt.xlabel("threhold")
plt.ylabel("correct suggestion rate")
# Out:
# Text(0, 0.5, 'correct suggestion rate')
